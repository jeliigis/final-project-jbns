# %%
#since we are also interested in the variable cost, we have to refer to an additional data set
#we first structure it and afterwards merge it with the other data bits

import pandas as pd
df_cost = pd.read_excel('../app/data/cost_hospitals.xlsx')

# %%
#make sure it uploaded correctly

df_cost.head()
# Out:
#    JAHR  KT                          Status              Inst  \
# 0  2008  BE  öffentlich oder subventioniert  Inselspital Bern
# 1  2009  BE  öffentlich oder subventioniert  Inselspital Bern
# 2  2010  BE                             NaN  Inselspital Bern
# 3  2011  BE                             NaN  Inselspital Bern
# 4  2012  BE                             NaN  Inselspital Bern
#
#                   Adr        Ort   Typ     KostAmbA    KostStatA  KostAmbP  \
# 0  Freiburgstrasse 18  3010 Bern  K111          NaN          NaN       NaN
# 1  Freiburgstrasse 18  3010 Bern  K111          NaN          NaN       NaN
# 2  Freiburgstrasse 18  3010 Bern  K111  274650903.0  636001888.0       0.0
# 3  Freiburgstrasse 18  3010 Bern  K111  281401666.0  665454486.0       0.0
# 4  Freiburgstrasse 18  3010 Bern  K111  311940148.0  700459585.0       NaN
#
#    KostStatP  KostAmbR   KostStatR  KostAmbB  KostStatB
# 0        NaN       NaN         NaN       NaN        NaN
# 1        NaN       NaN         NaN       NaN        NaN
# 2        0.0       0.0   9680385.0       0.0        0.0
# 3        0.0       0.0   9275349.0       0.0        0.0
# 4        NaN       0.0  10225005.0       NaN        NaN

# %%
#Es werden erst Daten ab dem Jahr 2010 benötigt
df_cost = df_cost[df_cost['JAHR'] >= 2010]

# %%
#zuordnen der Kantone nach Grossregionen

kanton_to_region= {
    'GE': 'Région lémanique', 'VD': 'Région lémanique', 'VS': 'Région lémanique',
    'BE': 'Espace Mittelland', 'FR': 'Espace Mittelland', 'SO': 'Espace Mittelland',
    'NE': 'Espace Mittelland', 'JU': 'Espace Mittelland',
    'BS': 'Nordwestschweiz', 'BL': 'Nordwestschweiz', 'AG': 'Nordwestschweiz',
    'ZH': 'Zürich',
    'GL': 'Ostschweiz', 'SH': 'Ostschweiz', 'AR': 'Ostschweiz', 'AI': 'Ostschweiz',
    'SG': 'Ostschweiz', 'GR': 'Ostschweiz', 'TG': 'Ostschweiz',
    'LU': 'Zentralschweiz', 'UR': 'Zentralschweiz', 'SZ': 'Zentralschweiz',
    'OW': 'Zentralschweiz', 'NW': 'Zentralschweiz', 'ZG': 'Zentralschweiz',
    'TI': 'Ticino'
}

# %%
#mapping anwenden
df_cost['Grossregion']= df_cost['KT'].map(kanton_to_region)

# %%
df_cost.head(20)
df_cost.query("Grossregion == 'Ticino'")
# Out:
#       JAHR  KT Status                                               Inst  \
# 393   2010  TI    NaN                     EOC Ente ospedaliero cantonale
# 394   2011  TI    NaN                     EOC Ente ospedaliero cantonale
# 395   2012  TI    NaN                     EOC Ente ospedaliero cantonale
# 396   2013  TI    NaN                     EOC Ente ospedaliero cantonale
# 397   2014  TI    NaN                     EOC Ente ospedaliero cantonale
# ...    ...  ..    ...                                                ...
# 4269  2021  TI    NaN  Clinica Dr Spinedi c/o Clinica Santa Croce SA ...
# 4270  2022  TI    NaN                       Clinica Fondazione G. Varini
# 4271  2022  TI    NaN  Clinica Dr Spinedi c/o Clinica Santa Croce SA ...
# 4272  2023  TI    NaN                       Clinica Fondazione G. Varini
# 4273  2023  TI    NaN  Clinica Dr Spinedi c/o Clinica Santa Croce SA ...
#
#                            Adr              Ort   Typ     KostAmbA  \
# 393           Viale Officina 3  6500 Bellinzona  K112  153838900.0
# 394           Viale Officina 3  6500 Bellinzona  K112  157542000.0
# 395           Viale Officina 3  6500 Bellinzona  K112  164459500.0
# 396           Viale Officina 3  6500 Bellinzona  K112  180590100.0
# 397           Viale Officina 3  6500 Bellinzona  K112  193444900.0
# ...                        ...              ...   ...          ...
# 4269           Via al Parco 27    6644 Orselina  K235          0.0
# 4270  Via Consiglio Mezzano 38    6644 Orselina  K235      95258.0
# 4271           Via al Parco 27    6644 Orselina  K235          0.0
# 4272  Via Consiglio Mezzano 38    6644 Orselina  K235      91299.0
# 4273           Via al Parco 27    6644 Orselina  K235          0.0
#
#         KostStatA  KostAmbP  KostStatP  KostAmbR   KostStatR  KostAmbB  \
# 393   358434500.0       0.0        0.0       0.0  16124900.0       0.0
# 394   371494100.0       0.0        0.0       0.0  16110800.0       0.0
# 395   360093500.0       NaN        NaN       0.0  17387800.0       NaN
# 396   375876100.0       NaN        NaN       0.0  18723700.0       NaN
# 397   383270300.0       NaN        NaN       0.0  19732500.0       NaN
# ...           ...       ...        ...       ...         ...       ...
# 4269     312749.0       NaN        NaN       NaN         NaN       NaN
# 4270    2527068.0       NaN        NaN       NaN         NaN       NaN
# 4271     350535.0       NaN        NaN       NaN         NaN       NaN
# 4272    2592932.0       NaN        NaN       NaN         NaN       NaN
# 4273     360060.0       NaN        NaN       NaN         NaN       NaN
#
#       KostStatB Grossregion
# 393         0.0      Ticino
# 394         0.0      Ticino
# 395         NaN      Ticino
# 396         NaN      Ticino
# 397         NaN      Ticino
# ...         ...         ...
# 4269        NaN      Ticino
# 4270        NaN      Ticino
# 4271        NaN      Ticino
# 4272        NaN      Ticino
# 4273        NaN      Ticino
#
# [188 rows x 16 columns]

# %%
#Spalten entfernen, die wir sicherlich nicht mehr benötigen

df_cost= df_cost.drop(columns=['Adr', 'Status', 'Ort'])

# %%
#überprüfen
df_cost.head()
# Out:
#    JAHR  KT              Inst   Typ     KostAmbA    KostStatA  KostAmbP  \
# 2  2010  BE  Inselspital Bern  K111  274650903.0  636001888.0       0.0
# 3  2011  BE  Inselspital Bern  K111  281401666.0  665454486.0       0.0
# 4  2012  BE  Inselspital Bern  K111  311940148.0  700459585.0       NaN
# 5  2013  BE  Inselspital Bern  K111  328085660.0  717552985.0       NaN
# 6  2014  BE  Inselspital Bern  K111  341840521.0  734454317.0       NaN
#
#    KostStatP  KostAmbR   KostStatR  KostAmbB  KostStatB        Grossregion
# 2        0.0       0.0   9680385.0       0.0        0.0  Espace Mittelland
# 3        0.0       0.0   9275349.0       0.0        0.0  Espace Mittelland
# 4        NaN       0.0  10225005.0       NaN        NaN  Espace Mittelland
# 5        NaN       0.0  10183933.0       NaN        NaN  Espace Mittelland
# 6        NaN       0.0  10256366.0       NaN        NaN  Espace Mittelland

# %%
#Darstellung, sodass pro Jahr und Grossregion die Summe der Kosten aus ambulant/akut und stationär/akut 
#sicherstellen, dass die Spalten KostAmbA und KostStatA numerisch sind
cost_cols = ['KostAmbA', 'KostStatA']
df_cost[cost_cols] = df_cost[cost_cols].apply(pd.to_numeric, errors='coerce')

#aggregiert: Summe pro Grossregion pro Jahr
#Gruppieren nach Jahr und Grossregion
grouped = df_cost.groupby(['JAHR', 'Grossregion'], as_index=False)[cost_cols]

# Aggregieren (Summe bilden)
summed = grouped.sum()

#Sortieren nach Jahr und Grossregion
df_region_year = summed.sort_values(['JAHR', 'Grossregion'])

#Schweiz als zusätzliche Kategorie anhängen
# Schweiz nur aus den Regionen bilden (vorhandene Schweiz-Zeilen ignorieren)
df_ch = (
    df_region_year[df_region_year['Grossregion'] != 'Schweiz']
    .groupby('JAHR', as_index=False)[cost_cols]
    .sum(min_count=1)
    .assign(Grossregion='Schweiz')
)
df_region_year = pd.concat([
    df_region_year[df_region_year['Grossregion'] != 'Schweiz'],
    df_ch
], ignore_index=True).sort_values(['JAHR', 'Grossregion'])

# %%
check = (
    df_region_year[df_region_year['Grossregion'] != 'Schweiz']
    .groupby('JAHR')[cost_cols].sum()
    - df_region_year[df_region_year['Grossregion'] == 'Schweiz']
      .set_index('JAHR')[cost_cols]
)
check.abs().max()   # sollte 0 (oder nur Rundungsreste) sein
# Out:
# KostAmbA     0.0
# KostStatA    0.0
# dtype: float64

# %%
df_region_year.head(8)
# Out:
#     JAHR        Grossregion      KostAmbA     KostStatA
# 0   2010  Espace Mittelland  1.003112e+09  2.687294e+09
# 1   2010    Nordwestschweiz  7.039205e+08  1.632927e+09
# 2   2010         Ostschweiz  4.827668e+08  1.504621e+09
# 3   2010   Région lémanique  9.297511e+08  2.268943e+09
# 98  2010            Schweiz  4.498723e+09  1.207283e+10
# 4   2010             Ticino  2.009135e+08  5.616815e+08
# 5   2010     Zentralschweiz  3.793588e+08  8.476163e+08
# 6   2010             Zürich  7.989004e+08  2.569751e+09

# %%
df_region_year.query("Grossregion == 'Schweiz'")
# Out:
#      JAHR Grossregion      KostAmbA     KostStatA
# 98   2010     Schweiz  4.498723e+09  1.207283e+10
# 99   2011     Schweiz  4.849648e+09  1.252642e+10
# 100  2012     Schweiz  5.269642e+09  1.327163e+10
# 101  2013     Schweiz  5.614162e+09  1.378030e+10
# 102  2014     Schweiz  5.922281e+09  1.434392e+10
# 103  2015     Schweiz  6.185046e+09  1.464289e+10
# 104  2016     Schweiz  6.657766e+09  1.490628e+10
# 105  2017     Schweiz  7.044607e+09  1.506224e+10
# 106  2018     Schweiz  7.225508e+09  1.498799e+10
# 107  2019     Schweiz  7.604105e+09  1.529399e+10
# 108  2020     Schweiz  7.841731e+09  1.556302e+10
# 109  2021     Schweiz  8.289039e+09  1.593126e+10
# 110  2022     Schweiz  8.712374e+09  1.623639e+10
# 111  2023     Schweiz  9.227304e+09  1.693895e+10

# %%
#Umbenennung/Standardisierung 
df_cost_ready = df_region_year.rename(columns={
    'JAHR': 'Jahr',
    'Grossregion': 'Region',
    'KostAmbA': 'KostAmbA',
    'KostStatA': 'KostStatA'
})

#Datensatz Cost ist ready :)

# %%
df_cost_ready.head(112)
df_cost_ready.iloc[50:100]
# Out:
#      Jahr             Region      KostAmbA     KostStatA
# 44   2016         Ostschweiz  7.478123e+08  1.901647e+09
# 45   2016   Région lémanique  1.452829e+09  2.793160e+09
# 104  2016            Schweiz  6.657766e+09  1.490628e+10
# 46   2016             Ticino  2.688797e+08  6.468468e+08
# 47   2016     Zentralschweiz  5.464966e+08  1.044610e+09
# 48   2016             Zürich  1.172426e+09  3.233744e+09
# 49   2017  Espace Mittelland  1.501473e+09  3.097126e+09
# 50   2017    Nordwestschweiz  1.113850e+09  2.257574e+09
# 51   2017         Ostschweiz  8.000035e+08  1.903387e+09
# 52   2017   Région lémanique  1.520637e+09  2.815141e+09
# 105  2017            Schweiz  7.044607e+09  1.506224e+10
# 53   2017             Ticino  2.908987e+08  6.533394e+08
# 54   2017     Zentralschweiz  5.701614e+08  1.070345e+09
# 55   2017             Zürich  1.247584e+09  3.265333e+09
# 56   2018  Espace Mittelland  1.530388e+09  3.079099e+09
# 57   2018    Nordwestschweiz  1.104857e+09  2.226750e+09
# 58   2018         Ostschweiz  8.251390e+08  1.907221e+09
# 59   2018   Région lémanique  1.559700e+09  2.847883e+09
# 106  2018            Schweiz  7.225508e+09  1.498799e+10
# 60   2018             Ticino  2.888615e+08  6.294871e+08
# 61   2018     Zentralschweiz  6.000268e+08  1.064114e+09
# 62   2018             Zürich  1.316535e+09  3.233436e+09
# 63   2019  Espace Mittelland  1.599823e+09  3.110271e+09
# 64   2019    Nordwestschweiz  1.132957e+09  2.273503e+09
# 65   2019         Ostschweiz  8.737091e+08  1.871719e+09
# 66   2019   Région lémanique  1.697338e+09  3.033896e+09
# 107  2019            Schweiz  7.604105e+09  1.529399e+10
# 67   2019             Ticino  3.020108e+08  6.322578e+08
# 68   2019     Zentralschweiz  6.235073e+08  1.079026e+09
# 69   2019             Zürich  1.374759e+09  3.293320e+09
# 70   2020  Espace Mittelland  1.627503e+09  3.145112e+09
# 71   2020    Nordwestschweiz  1.181255e+09  2.302305e+09
# 72   2020         Ostschweiz  9.018170e+08  1.910558e+09
# 73   2020   Région lémanique  1.785777e+09  3.136119e+09
# 108  2020            Schweiz  7.841731e+09  1.556302e+10
# 74   2020             Ticino  3.154219e+08  6.460395e+08
# 75   2020     Zentralschweiz  6.371940e+08  1.114886e+09
# 76   2020             Zürich  1.392763e+09  3.308002e+09
# 77   2021  Espace Mittelland  1.726705e+09  3.229028e+09
# 78   2021    Nordwestschweiz  1.248138e+09  2.392871e+09
# 79   2021         Ostschweiz  9.659280e+08  1.937588e+09
# 80   2021   Région lémanique  1.869337e+09  3.234932e+09
# 109  2021            Schweiz  8.289039e+09  1.593126e+10
# 81   2021             Ticino  3.359567e+08  6.343397e+08
# 82   2021     Zentralschweiz  6.755069e+08  1.148783e+09
# 83   2021             Zürich  1.467467e+09  3.353721e+09
# 84   2022  Espace Mittelland  1.827148e+09  3.308813e+09
# 85   2022    Nordwestschweiz  1.301291e+09  2.440637e+09
# 86   2022         Ostschweiz  1.035690e+09  1.947201e+09
# 87   2022   Région lémanique  1.944305e+09  3.275663e+09

# %%
#als nächstes kümmern wir uns um die weiteren drei Datensätze

df_staff = pd.read_excel('../app/data/staff.xlsx', skiprows=2) #skipping the first two rows as they only contain the description / title
df_services = pd.read_excel('../app/data/services.xlsx', skiprows=2)
df_infrastructure = pd.read_excel('../app/data/infrastructure.xlsx', skiprows=2)

# %%
#having a look at the datasets to get a feeling how to merge them into one
df_staff.info()
df_staff.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1 non-null      object
#  1   Unnamed: 1   1 non-null      object
#  2   Unnamed: 2   4 non-null      float64
#  3   Unnamed: 3   4 non-null      object
#  4   Unnamed: 4   12 non-null     float64
#  5   Unnamed: 5   12 non-null     object
#  6   Unnamed: 6   96 non-null     object
#  7   Unnamed: 7   96 non-null     object
#  8   Unnamed: 8   96 non-null     object
#  9   Unnamed: 9   96 non-null     object
#  10  Unnamed: 10  96 non-null     int64
#  11  Unnamed: 11  96 non-null     object
#  12  2010         96 non-null     float64
#  13  2011         96 non-null     float64
#  14  2012         96 non-null     float64
#  15  2013         96 non-null     float64
#  16  2014         96 non-null     float64
#  17  2015         96 non-null     float64
#  18  2016         96 non-null     float64
#  19  2017         96 non-null     float64
#  20  2018         96 non-null     float64
#  21  2019         96 non-null     float64
#  22  2020         96 non-null     float64
#  23  2021         96 non-null     float64
#  24  2022         96 non-null     float64
#  25  2023         96 non-null     float64
# dtypes: float64(16), int64(1), object(9)
# memory usage: 19.6+ KB
#   Unnamed: 0                                 Unnamed: 1  Unnamed: 2  \
# 0        VZA  Internes Personal in Vollzeitäquivalenten         1.0
# 1        NaN                                        NaN         NaN
# 2        NaN                                        NaN         NaN
# 3        NaN                                        NaN         NaN
# 4        NaN                                        NaN         NaN
#
#        Unnamed: 3  Unnamed: 4                   Unnamed: 5 Unnamed: 6  \
# 0  << Ärzteschaft        12.0  << Allgemeine Krankenhäuser       8100
# 1             NaN         NaN                          NaN          A
# 2             NaN         NaN                          NaN          B
# 3             NaN         NaN                          NaN          C
# 4             NaN         NaN                          NaN          D
#
#           Unnamed: 7          Unnamed: 8          Unnamed: 9  ...      2014  \
# 0            Schweiz  Geschlecht - Total  Geschlecht - Total  ...  17525.92
# 1   Région lémanique  Geschlecht - Total  Geschlecht - Total  ...   4412.64
# 2  Espace Mittelland  Geschlecht - Total  Geschlecht - Total  ...   3404.14
# 3    Nordwestschweiz  Geschlecht - Total  Geschlecht - Total  ...   2619.35
# 4             Zürich  Geschlecht - Total  Geschlecht - Total  ...   2994.01
#
#        2015      2016      2017      2018      2019      2020      2021  \
# 0  18285.13  19139.73  19486.05  20210.63  21132.86  21678.85  22185.89
# 1   4502.48   4668.35   4800.56   4893.25   5238.53   5475.00   5622.53
# 2   3570.26   3767.41   3888.98   4157.41   4484.84   4502.07   4566.20
# 3   2687.73   2808.51   2799.83   2838.82   2945.39   3006.26   3024.93
# 4   3147.39   3277.06   3324.22   3536.40   3596.79   3690.91   3798.37
#
#        2022      2023
# 0  22798.20  23780.07
# 1   5686.23   5832.68
# 2   4703.81   4906.69
# 3   3141.05   3370.78
# 4   3883.18   4035.89
#
# [5 rows x 26 columns]

# %%
df_infrastructure.info()
df_infrastructure.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  8 non-null      object
#  1   Unnamed: 1  8 non-null      object
#  2   Unnamed: 2  16 non-null     object
#  3   Unnamed: 3  16 non-null     object
#  4   Unnamed: 4  128 non-null    object
#  5   Unnamed: 5  128 non-null    object
#  6   2013        128 non-null    int64
#  7   2014        128 non-null    int64
#  8   2015        128 non-null    int64
#  9   2016        128 non-null    int64
#  10  2017        128 non-null    int64
#  11  2018        128 non-null    int64
#  12  2019        128 non-null    int64
#  13  2020        128 non-null    int64
#  14  2021        128 non-null    int64
#  15  2022        128 non-null    int64
#  16  2023        128 non-null    int64
# dtypes: int64(11), object(6)
# memory usage: 17.1+ KB
#      Unnamed: 0          Unnamed: 1    Unnamed: 2     Unnamed: 3 Unnamed: 4  \
# 0  ANGIOGRAPHIE  Angiographiegeräte  Anzahl_Infra  Anzahl Geräte       8100
# 1           NaN                 NaN           NaN            NaN          A
# 2           NaN                 NaN           NaN            NaN          B
# 3           NaN                 NaN           NaN            NaN          C
# 4           NaN                 NaN           NaN            NaN          D
#
#           Unnamed: 5  2013  2014  2015  2016  2017  2018  2019  2020  2021  \
# 0            Schweiz   137   138   146   143   136   136   128   141   145
# 1   Région lémanique    28    29    29    26    25    27    23    24    23
# 2  Espace Mittelland    27    27    27    25    25    24    24    28    29
# 3    Nordwestschweiz    20    20    21    22    22    22    19    21    21
# 4             Zürich    25    25    25    25    28    28    25    32    32
#
#    2022  2023
# 0   154   152
# 1    27    28
# 2    29    28
# 3    23    23
# 4    33    30

# %%
df_services.info()
df_services.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  9 non-null      object
#  1   Unnamed: 1  9 non-null      object
#  2   Unnamed: 2  72 non-null     object
#  3   Unnamed: 3  72 non-null     object
#  4   Unnamed: 4  216 non-null    int64
#  5   Unnamed: 5  216 non-null    object
#  6   2010        216 non-null    object
#  7   2011        216 non-null    object
#  8   2012        216 non-null    object
#  9   2013        216 non-null    object
#  10  2014        216 non-null    object
#  11  2015        216 non-null    object
#  12  2016        216 non-null    object
#  13  2017        216 non-null    object
#  14  2018        216 non-null    object
#  15  2019        216 non-null    object
#  16  2020        216 non-null    object
#  17  2021        216 non-null    object
#  18  2022        216 non-null    object
#  19  2023        216 non-null    object
# dtypes: int64(1), object(19)
# memory usage: 33.9+ KB
#          Unnamed: 0       Unnamed: 1 Unnamed: 2        Unnamed: 3  Unnamed: 4  \
# 0  Anzahl_Spitaeler  Anzahl Spitäler       8100           Schweiz          12
# 1               NaN              NaN        NaN               NaN           1
# 2               NaN              NaN        NaN               NaN           2
# 3               NaN              NaN          A  Région lémanique          12
# 4               NaN              NaN        NaN               NaN           1
#
#                     Unnamed: 5 2010 2011 2012 2013 2014 2015 2016 2017 2018  \
# 0  << Allgemeine Krankenhäuser  121  120  116  113  108  106  102  102  102
# 1       ....Zentrumsversorgung   30   30   30   39   39   40   44   44   44
# 2          ....Grundversorgung   91   90   86   74   69   66   58   58   58
# 3  << Allgemeine Krankenhäuser   23   23   23   19   17   17   17   17   17
# 4       ....Zentrumsversorgung    7    7    7    5    5    5    7    7    7
#
#   2019 2020 2021 2022 2023
# 0  105  106  104  101  101
# 1   44   44   44   45   44
# 2   61   62   60   56   57
# 3   17   18   18   20   20
# 4    7    7    7    7    7

# %%
#before merging we're doing a rough clean so merging will be easier
#first: remove the first and eigth to eleventh column in the staff dataset
df_staff = df_staff.drop(columns=["Unnamed: 0", "Unnamed: 1", "Unnamed: 8", "Unnamed: 9", "Unnamed: 10", "Unnamed: 11"]) #removing it this way to avoid removing more columns later on with another name if i run the code again (dont know if that makes sense)
df_staff.head()
# Out:
#    Unnamed: 2      Unnamed: 3  Unnamed: 4                   Unnamed: 5  \
# 0         1.0  << Ärzteschaft        12.0  << Allgemeine Krankenhäuser
# 1         NaN             NaN         NaN                          NaN
# 2         NaN             NaN         NaN                          NaN
# 3         NaN             NaN         NaN                          NaN
# 4         NaN             NaN         NaN                          NaN
#
#   Unnamed: 6         Unnamed: 7      2010      2011      2012      2013  \
# 0       8100            Schweiz  15723.60  16460.73  16695.57  16952.75
# 1          A   Région lémanique   3926.23   4204.06   4314.79   4240.59
# 2          B  Espace Mittelland   3259.08   3237.56   3313.89   3403.62
# 3          C    Nordwestschweiz   2267.93   2699.09   2564.04   2589.06
# 4          D             Zürich   2761.42   2684.31   2730.89   2828.06
#
#        2014      2015      2016      2017      2018      2019      2020  \
# 0  17525.92  18285.13  19139.73  19486.05  20210.63  21132.86  21678.85
# 1   4412.64   4502.48   4668.35   4800.56   4893.25   5238.53   5475.00
# 2   3404.14   3570.26   3767.41   3888.98   4157.41   4484.84   4502.07
# 3   2619.35   2687.73   2808.51   2799.83   2838.82   2945.39   3006.26
# 4   2994.01   3147.39   3277.06   3324.22   3536.40   3596.79   3690.91
#
#        2021      2022      2023
# 0  22185.89  22798.20  23780.07
# 1   5622.53   5686.23   5832.68
# 2   4566.20   4703.81   4906.69
# 3   3024.93   3141.05   3370.78
# 4   3798.37   3883.18   4035.89

# %%
#step 2: (re)name the columns
#for df_staff
df_staff.columns = ["Berufsgruppe_ID",
                    "Berufsgruppe", 
                    "Krankenhaus_Typ_ID", 
                    "Krankenhaus_Typ", 
                    "Region_ID", 
                    "Region", 
                    "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021", "2022", "2023"]
df_staff.head()

#for df_services
df_services.columns = ["Kat_Services",
                       "Kat_Services_Beschreibung",
                       "Region_ID", #nachher noch duplicates löschen! sind in jedem dataset vorhanden
                       "Region", #nachher noch duplicates löschen! sind in jedem dataset vorhanden
                       "Krankenhaus_Typ_ID", #nachher noch duplicates löschen! sind in jedem dataset vorhanden
                       "Krankenhaus_Typ", #nachher noch duplicates löschen! sind in jedem dataset vorhanden
                       "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021", "2022", "2023"]
df_services.head()

#for df_infrastructure
df_infrastructure.columns = ["Gerät_Kurzname",
                             "Gerät_Beschreibung",
                             "Kat_Infrastructure", #Anzahl_Infra / Untersuchungen_Total
                             "Kat_Infrastructure_Beschreibung",
                             "Region_ID",
                             "Region",
                             "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021", "2022", "2023"]
df_infrastructure.head
# Out:
# <bound method NDFrame.head of     Gerät_Kurzname  Gerät_Beschreibung Kat_Infrastructure  \
# 0     ANGIOGRAPHIE  Angiographiegeräte       Anzahl_Infra
# 1              NaN                 NaN                NaN
# 2              NaN                 NaN                NaN
# 3              NaN                 NaN                NaN
# 4              NaN                 NaN                NaN
# ..             ...                 ...                ...
# 123            NaN                 NaN                NaN
# 124            NaN                 NaN                NaN
# 125            NaN                 NaN                NaN
# 126            NaN                 NaN                NaN
# 127            NaN                 NaN                NaN
#
#     Kat_Infrastructure_Beschreibung Region_ID             Region  2013  2014  \
# 0                     Anzahl Geräte      8100            Schweiz   137   138
# 1                               NaN         A   Région lémanique    28    29
# 2                               NaN         B  Espace Mittelland    27    27
# 3                               NaN         C    Nordwestschweiz    20    20
# 4                               NaN         D             Zürich    25    25
# ..                              ...       ...                ...   ...   ...
# 123                             NaN         C    Nordwestschweiz  6097  6823
# 124                             NaN         D             Zürich  7004  7503
# 125                             NaN         E         Ostschweiz  2839  3080
# 126                             NaN         F     Zentralschweiz  1193  1335
# 127                             NaN         G             Ticino  1843  2161
#
#      2015  2016   2017   2018   2019   2020   2021   2022   2023
# 0     146   143    136    136    128    141    145    154    152
# 1      29    26     25     27     23     24     23     27     28
# 2      27    25     25     24     24     28     29     29     28
# 3      21    22     22     22     19     21     21     23     23
# 4      25    25     28     28     25     32     32     33     30
# ..    ...   ...    ...    ...    ...    ...    ...    ...    ...
# 123  5626  8546   8410   8246   8178   7654   7817  11059  12340
# 124  8128  8617  10249  10925  11900  12140  13427  14177  14851
# 125  3512  3706   4438   5391   5577   6032   7050   8582   8749
# 126  1584  1697   1932   2162   2521   2675   3394   3774   4070
# 127   812  2725   2709   2748   3011   3261   3883   4155   4258
#
# [128 rows x 17 columns]>

# %%
#step 3: bring the three datasets staff, services and infrastructure in a (not already perfect) tidy data layout before looking at the cost dataset
#generating "new" datasets to still have the "original version" if something goes wrong, maybe changing the name later on to make it more systematic
#for pd_staff
id_vars = ["Berufsgruppe_ID", "Berufsgruppe", "Krankenhaus_Typ_ID", "Krankenhaus_Typ", "Region_ID", "Region"] #define all variables that should stay in pd_staff
df_staff_melt = df_staff.melt(id_vars = id_vars, var_name = "Jahr", value_name = "Anzahl VZÄ") #melt the years in staff into a column

###recognized the data has a lot of NaN because e.g. the berufsgruppe_id is only for the first observation, so adding the first value for all the following ones
### so we have to add them with df.fillna (see cheat sheet)
columns_staff_ffill =["Berufsgruppe_ID", "Berufsgruppe", "Krankenhaus_Typ_ID", "Krankenhaus_Typ"] #creating a list which mentions for which columns we want fo ffill NaN with the values above, had an error when i ran the code without defining the columns
df_staff_melt[columns_staff_ffill] = df_staff_melt[columns_staff_ffill].ffill()
df_staff_melt.head(50)
# Out:
#     Berufsgruppe_ID                           Berufsgruppe  \
# 0               1.0                         << Ärzteschaft
# 1               1.0                         << Ärzteschaft
# 2               1.0                         << Ärzteschaft
# 3               1.0                         << Ärzteschaft
# 4               1.0                         << Ärzteschaft
# 5               1.0                         << Ärzteschaft
# 6               1.0                         << Ärzteschaft
# 7               1.0                         << Ärzteschaft
# 8               1.0                         << Ärzteschaft
# 9               1.0                         << Ärzteschaft
# 10              1.0                         << Ärzteschaft
# 11              1.0                         << Ärzteschaft
# 12              1.0                         << Ärzteschaft
# 13              1.0                         << Ärzteschaft
# 14              1.0                         << Ärzteschaft
# 15              1.0                         << Ärzteschaft
# 16              1.0                         << Ärzteschaft
# 17              1.0                         << Ärzteschaft
# 18              1.0                         << Ärzteschaft
# 19              1.0                         << Ärzteschaft
# 20              1.0                         << Ärzteschaft
# 21              1.0                         << Ärzteschaft
# 22              1.0                         << Ärzteschaft
# 23              1.0                         << Ärzteschaft
# 24              8.0                      << Pflegepersonal
# 25              8.0                      << Pflegepersonal
# 26              8.0                      << Pflegepersonal
# 27              8.0                      << Pflegepersonal
# 28              8.0                      << Pflegepersonal
# 29              8.0                      << Pflegepersonal
# 30              8.0                      << Pflegepersonal
# 31              8.0                      << Pflegepersonal
# 32              8.0                      << Pflegepersonal
# 33              8.0                      << Pflegepersonal
# 34              8.0                      << Pflegepersonal
# 35              8.0                      << Pflegepersonal
# 36              8.0                      << Pflegepersonal
# 37              8.0                      << Pflegepersonal
# 38              8.0                      << Pflegepersonal
# 39              8.0                      << Pflegepersonal
# 40              8.0                      << Pflegepersonal
# 41              8.0                      << Pflegepersonal
# 42              8.0                      << Pflegepersonal
# 43              8.0                      << Pflegepersonal
# 44              8.0                      << Pflegepersonal
# 45              8.0                      << Pflegepersonal
# 46              8.0                      << Pflegepersonal
# 47              8.0                      << Pflegepersonal
# 48             15.0  << Medizinisch - technisches Personal
# 49             15.0  << Medizinisch - technisches Personal
#
#     Krankenhaus_Typ_ID              Krankenhaus_Typ Region_ID  \
# 0                 12.0  << Allgemeine Krankenhäuser      8100
# 1                 12.0  << Allgemeine Krankenhäuser         A
# 2                 12.0  << Allgemeine Krankenhäuser         B
# 3                 12.0  << Allgemeine Krankenhäuser         C
# 4                 12.0  << Allgemeine Krankenhäuser         D
# 5                 12.0  << Allgemeine Krankenhäuser         E
# 6                 12.0  << Allgemeine Krankenhäuser         F
# 7                 12.0  << Allgemeine Krankenhäuser         G
# 8                  1.0       ....Zentrumsversorgung      8100
# 9                  1.0       ....Zentrumsversorgung         A
# 10                 1.0       ....Zentrumsversorgung         B
# 11                 1.0       ....Zentrumsversorgung         C
# 12                 1.0       ....Zentrumsversorgung         D
# 13                 1.0       ....Zentrumsversorgung         E
# 14                 1.0       ....Zentrumsversorgung         F
# 15                 1.0       ....Zentrumsversorgung         G
# 16                 2.0          ....Grundversorgung      8100
# 17                 2.0          ....Grundversorgung         A
# 18                 2.0          ....Grundversorgung         B
# 19                 2.0          ....Grundversorgung         C
# 20                 2.0          ....Grundversorgung         D
# 21                 2.0          ....Grundversorgung         E
# 22                 2.0          ....Grundversorgung         F
# 23                 2.0          ....Grundversorgung         G
# 24                12.0  << Allgemeine Krankenhäuser      8100
# 25                12.0  << Allgemeine Krankenhäuser         A
# 26                12.0  << Allgemeine Krankenhäuser         B
# 27                12.0  << Allgemeine Krankenhäuser         C
# 28                12.0  << Allgemeine Krankenhäuser         D
# 29                12.0  << Allgemeine Krankenhäuser         E
# 30                12.0  << Allgemeine Krankenhäuser         F
# 31                12.0  << Allgemeine Krankenhäuser         G
# 32                 1.0       ....Zentrumsversorgung      8100
# 33                 1.0       ....Zentrumsversorgung         A
# 34                 1.0       ....Zentrumsversorgung         B
# 35                 1.0       ....Zentrumsversorgung         C
# 36                 1.0       ....Zentrumsversorgung         D
# 37                 1.0       ....Zentrumsversorgung         E
# 38                 1.0       ....Zentrumsversorgung         F
# 39                 1.0       ....Zentrumsversorgung         G
# 40                 2.0          ....Grundversorgung      8100
# 41                 2.0          ....Grundversorgung         A
# 42                 2.0          ....Grundversorgung         B
# 43                 2.0          ....Grundversorgung         C
# 44                 2.0          ....Grundversorgung         D
# 45                 2.0          ....Grundversorgung         E
# 46                 2.0          ....Grundversorgung         F
# 47                 2.0          ....Grundversorgung         G
# 48                12.0  << Allgemeine Krankenhäuser      8100
# 49                12.0  << Allgemeine Krankenhäuser         A
#
#                Region  Jahr  Anzahl VZÄ
# 0             Schweiz  2010    15723.60
# 1    Région lémanique  2010     3926.23
# 2   Espace Mittelland  2010     3259.08
# 3     Nordwestschweiz  2010     2267.93
# 4              Zürich  2010     2761.42
# 5          Ostschweiz  2010     1883.66
# 6      Zentralschweiz  2010     1051.98
# 7              Ticino  2010      573.30
# 8             Schweiz  2010    12154.95
# 9    Région lémanique  2010     3393.85
# 10  Espace Mittelland  2010     2646.83
# 11    Nordwestschweiz  2010     1890.73
# 12             Zürich  2010     1919.21
# 13         Ostschweiz  2010     1185.05
# 14     Zentralschweiz  2010      661.90
# 15             Ticino  2010      457.38
# 16            Schweiz  2010     3568.65
# 17   Région lémanique  2010      532.38
# 18  Espace Mittelland  2010      612.25
# 19    Nordwestschweiz  2010      377.20
# 20             Zürich  2010      842.21
# 21         Ostschweiz  2010      698.61
# 22     Zentralschweiz  2010      390.08
# 23             Ticino  2010      115.92
# 24            Schweiz  2010    47591.48
# 25   Région lémanique  2010    11948.53
# 26  Espace Mittelland  2010    10862.19
# 27    Nordwestschweiz  2010     5780.76
# 28             Zürich  2010     7634.84
# 29         Ostschweiz  2010     5640.01
# 30     Zentralschweiz  2010     3651.24
# 31             Ticino  2010     2073.91
# 32            Schweiz  2010    32955.09
# 33   Région lémanique  2010     9387.96
# 34  Espace Mittelland  2010     8178.29
# 35    Nordwestschweiz  2010     4069.32
# 36             Zürich  2010     4598.85
# 37         Ostschweiz  2010     3144.79
# 38     Zentralschweiz  2010     2072.22
# 39             Ticino  2010     1503.66
# 40            Schweiz  2010    14636.39
# 41   Région lémanique  2010     2560.57
# 42  Espace Mittelland  2010     2683.90
# 43    Nordwestschweiz  2010     1711.44
# 44             Zürich  2010     3035.99
# 45         Ostschweiz  2010     2495.22
# 46     Zentralschweiz  2010     1579.02
# 47             Ticino  2010      570.25
# 48            Schweiz  2010    10757.05
# 49   Région lémanique  2010     2396.80

# %%
###for pd_services###
id_vars = ["Kat_Services", "Kat_Services_Beschreibung", "Region_ID", "Region", "Krankenhaus_Typ_ID", "Krankenhaus_Typ"] #define all variables that should stay in pd_services (can just overwrite the list above)
df_services_melt = df_services.melt(id_vars = id_vars, var_name = "Jahr", value_name = "Anzahl Kat_Services") #noch Kat-Services besser machen, so dass Anzahl Spitäler eine Spalte, Anzahl Betten etc.

#fill the missing values with df.fillna
columns_services_ffill = ["Kat_Services", "Kat_Services_Beschreibung", "Region_ID", "Region"]
df_services_melt[columns_services_ffill] = df_services_melt[columns_services_ffill].ffill()
df_services_melt.head(50)

### pivoting to get the Kat_Services column as seperate colums (sodass Anzahl_kat_services unterteilt wird und Anzahl Spitäler, Anzahl Betten etc. eigene spalten sind)
#drop the Kat_Services_Beschreibung to make it easier
df_services_melt = df_services_melt.drop(columns=["Kat_Services_Beschreibung"])
###pivoting
df_services_melt = df_services_melt.pivot(index=["Region_ID", "Region", "Krankenhaus_Typ_ID", "Krankenhaus_Typ", "Jahr"], columns="Kat_Services", values="Anzahl Kat_Services").reset_index()
df_services_melt.head(20)
# Out:
# Kat_Services Region_ID   Region  Krankenhaus_Typ_ID         Krankenhaus_Typ  \
# 0                 8100  Schweiz                   1  ....Zentrumsversorgung
# 1                 8100  Schweiz                   1  ....Zentrumsversorgung
# 2                 8100  Schweiz                   1  ....Zentrumsversorgung
# 3                 8100  Schweiz                   1  ....Zentrumsversorgung
# 4                 8100  Schweiz                   1  ....Zentrumsversorgung
# 5                 8100  Schweiz                   1  ....Zentrumsversorgung
# 6                 8100  Schweiz                   1  ....Zentrumsversorgung
# 7                 8100  Schweiz                   1  ....Zentrumsversorgung
# 8                 8100  Schweiz                   1  ....Zentrumsversorgung
# 9                 8100  Schweiz                   1  ....Zentrumsversorgung
# 10                8100  Schweiz                   1  ....Zentrumsversorgung
# 11                8100  Schweiz                   1  ....Zentrumsversorgung
# 12                8100  Schweiz                   1  ....Zentrumsversorgung
# 13                8100  Schweiz                   1  ....Zentrumsversorgung
# 14                8100  Schweiz                   2     ....Grundversorgung
# 15                8100  Schweiz                   2     ....Grundversorgung
# 16                8100  Schweiz                   2     ....Grundversorgung
# 17                8100  Schweiz                   2     ....Grundversorgung
# 18                8100  Schweiz                   2     ....Grundversorgung
# 19                8100  Schweiz                   2     ....Grundversorgung
#
# Kat_Services  Jahr Anzahl_Spitaeler Betten_Total Betten_akut Betten_geb  \
# 0             2010               30        17031       13937          *
# 1             2011               30        17124       13829          *
# 2             2012               30        17171       14198          *
# 3             2013               39        18824       16205          *
# 4             2014               39        18666       16123          *
# 5             2015               40        18601       16065          *
# 6             2016               44        19560       16809          *
# 7             2017               44        19790       16914          *
# 8             2018               44        19538       16777          *
# 9             2019               44        19637       16807          *
# 10            2020               44        19241       16440          *
# 11            2021               44        19198       16389          *
# 12            2022               45        19118       16367          *
# 13            2023               44        18863       16074          *
# 14            2010               91         9085        8439          *
# 15            2011               90         8940        8259          *
# 16            2012               86         8693        7953          *
# 17            2013               74         6241        5576          *
# 18            2014               69         6237        5519          *
# 19            2015               66         6118        5407          *
#
# Kat_Services Betten_psy Betten_reha Bettenbelegung Bettenbetriebstage  \
# 0                  1032        2063             93            6216484
# 1                  1052        2243             93            6250270
# 2                  1031        1942             93            6284578
# 3                   893        1726             96            6870815
# 4                   853        1690             97            6812962
# 5                   891        1645             85            6789399
# 6                   989        1763             87            7159126
# 7                   984        1892             85            7223315
# 8                   957        1804             85            7131376
# 9                  1075        1754             86            7167383
# 10                 1117        1685             81            7042364
# 11                 1105        1705             83            7007409
# 12                 1154        1598             86            6978238
# 13                 1161        1628             86            6884932
# 14                  166         480             91            3315849
# 15                  173         507             92            3262957
# 16                  225         516             89            3181754
# 17                  232         434             90            2278028
# 18                  273         445             91            2276615
# 19                  259         453             77            2233143
#
# Kat_Services Pflegetage_M_365
# 0                     5784342
# 1                     5825193
# 2                     5846935
# 3                     6570401
# 4                     6620331
# 5                     5797439
# 6                     6206669
# 7                     6153058
# 8                     6087902
# 9                     6151269
# 10                    5684562
# 11                    5826225
# 12                    5978858
# 13                    5933270
# 14                    3025719
# 15                    2997891
# 16                    2825373
# 17                    2058768
# 18                    2081120
# 19                    1712377

# %%
###for pd.infrastructure
id_vars = ["Gerät_Kurzname", "Gerät_Beschreibung", "Kat_Infrastructure", "Kat_Infrastructure_Beschreibung", "Region_ID", "Region"] #define all variables that should stay in pd_infrastructure
df_infrastructure_melt = df_infrastructure.melt(id_vars = id_vars, var_name = "Jahr", value_name = "Anzahl Infrastructure") #melt the years into a column

#using fffilna again
columns_infrastructure_ffill = ["Gerät_Kurzname", "Gerät_Beschreibung", "Kat_Infrastructure", "Kat_Infrastructure_Beschreibung"]
df_infrastructure_melt[columns_infrastructure_ffill] = df_infrastructure_melt[columns_infrastructure_ffill].ffill()
df_infrastructure_melt.head()


###pivoting because "Untersuchungen" and "Anzahl Geräte is in one column" --> Kat_Infrastructure and Kat_Infrastructure_Beschreibung are duplicates, so dropping Beschreibung first
df_infrastructure_melt = df_infrastructure_melt.drop(columns=["Kat_Infrastructure_Beschreibung"])
df_infrastructure_melt = df_infrastructure_melt.pivot(index=["Gerät_Kurzname", "Gerät_Beschreibung", "Region_ID", "Region", "Jahr"], columns="Kat_Infrastructure", values="Anzahl Infrastructure").reset_index()
df_infrastructure_melt.head(60)

df_infrastructure.drop(columns=['Gerät_Kurzname', ])
# Out:
#      Gerät_Beschreibung Kat_Infrastructure Kat_Infrastructure_Beschreibung  \
# 0    Angiographiegeräte       Anzahl_Infra                   Anzahl Geräte
# 1                   NaN                NaN                             NaN
# 2                   NaN                NaN                             NaN
# 3                   NaN                NaN                             NaN
# 4                   NaN                NaN                             NaN
# ..                  ...                ...                             ...
# 123                 NaN                NaN                             NaN
# 124                 NaN                NaN                             NaN
# 125                 NaN                NaN                             NaN
# 126                 NaN                NaN                             NaN
# 127                 NaN                NaN                             NaN
#
#     Region_ID             Region  2013  2014  2015  2016   2017   2018   2019  \
# 0        8100            Schweiz   137   138   146   143    136    136    128
# 1           A   Région lémanique    28    29    29    26     25     27     23
# 2           B  Espace Mittelland    27    27    27    25     25     24     24
# 3           C    Nordwestschweiz    20    20    21    22     22     22     19
# 4           D             Zürich    25    25    25    25     28     28     25
# ..        ...                ...   ...   ...   ...   ...    ...    ...    ...
# 123         C    Nordwestschweiz  6097  6823  5626  8546   8410   8246   8178
# 124         D             Zürich  7004  7503  8128  8617  10249  10925  11900
# 125         E         Ostschweiz  2839  3080  3512  3706   4438   5391   5577
# 126         F     Zentralschweiz  1193  1335  1584  1697   1932   2162   2521
# 127         G             Ticino  1843  2161   812  2725   2709   2748   3011
#
#       2020   2021   2022   2023
# 0      141    145    154    152
# 1       24     23     27     28
# 2       28     29     29     28
# 3       21     21     23     23
# 4       32     32     33     30
# ..     ...    ...    ...    ...
# 123   7654   7817  11059  12340
# 124  12140  13427  14177  14851
# 125   6032   7050   8582   8749
# 126   2675   3394   3774   4070
# 127   3261   3883   4155   4258
#
# [128 rows x 16 columns]

# %% [markdown]
# Getting an overview over the datasets and sorting them the same way to see what has to be done now
#
# 1) Tidying services

# %%
###dropping the Gerät_Beschreibung, created a new cell above, initially i did this in the pivoting sector below but than i cant run the code again because it gives an error the column doesnst exist anymore
df_services_melt = df_services_melt.drop(columns=["Krankenhaus_Typ_ID"])

# %%
###noticed in the code below (while pivoting) that we have some duplicate values why which we cant pivot, so we tried identifying them and dropping them
###df_services_melt.head(50)
###df_services_melt.duplicated(subset=["Region_ID", "Region", "Jahr", "Krankenhaus_Typ"]).sum()

###code isn't useful anymore as i just adjusted the data in the excel cause i wasnt able to do it in python

# %%
df_services_melt = df_services_melt.sort_values(by=["Jahr", "Region_ID"])
df_services_melt.head()

###changing the different Krankenhaus_Typs to different columns
df_services_melt = df_services_melt.pivot(index=["Region_ID", "Region", "Jahr"], columns="Krankenhaus_Typ", values=["Anzahl_Spitaeler", "Betten_Total", "Betten_akut", "Betten_geb", "Betten_psy", "Betten_reha", "Bettenbelegung", "Bettenbetriebstage", "Pflegetage_M_365"]).reset_index()
df_services_melt.head()
# Out:
#                 Region_ID   Region  Jahr    Anzahl_Spitaeler  \
# Krankenhaus_Typ                          ....Grundversorgung
# 0                    8100  Schweiz  2010                  91
# 1                    8100  Schweiz  2011                  90
# 2                    8100  Schweiz  2012                  86
# 3                    8100  Schweiz  2013                  74
# 4                    8100  Schweiz  2014                  69
#
#                                                                     \
# Krankenhaus_Typ ....Zentrumsversorgung << Allgemeine Krankenhäuser
# 0                                   30                         121
# 1                                   30                         120
# 2                                   30                         116
# 3                                   39                         113
# 4                                   39                         108
#
#                        Betten_Total                         \
# Krankenhaus_Typ ....Grundversorgung ....Zentrumsversorgung
# 0                              9085                  17031
# 1                              8940                  17124
# 2                              8693                  17171
# 3                              6241                  18824
# 4                              6237                  18666
#
#                                                     Betten_akut  ...  \
# Krankenhaus_Typ << Allgemeine Krankenhäuser ....Grundversorgung  ...
# 0                                     26116                8439  ...
# 1                                     26064                8259  ...
# 2                                     25864                7953  ...
# 3                                     25065                5576  ...
# 4                                     24903                5519  ...
#
#                                 Betten_reha      Bettenbelegung  \
# Krankenhaus_Typ << Allgemeine Krankenhäuser ....Grundversorgung
# 0                                      2542                  91
# 1                                      2751                  92
# 2                                      2457                  89
# 3                                      2160                  90
# 4                                      2135                  91
#
#                                                                     \
# Krankenhaus_Typ ....Zentrumsversorgung << Allgemeine Krankenhäuser
# 0                                   93                          92
# 1                                   93                          93
# 2                                   93                          92
# 3                                   96                          94
# 4                                   97                          96
#
#                  Bettenbetriebstage                         \
# Krankenhaus_Typ ....Grundversorgung ....Zentrumsversorgung
# 0                           3315849                6216484
# 1                           3262957                6250270
# 2                           3181754                6284578
# 3                           2278028                6870815
# 4                           2276615                6812962
#
#                                                Pflegetage_M_365  \
# Krankenhaus_Typ << Allgemeine Krankenhäuser ....Grundversorgung
# 0                                   9532333             3025719
# 1                                   9513227             2997891
# 2                                   9466332             2825373
# 3                                   9148843             2058768
# 4                                   9089577             2081120
#
#
# Krankenhaus_Typ ....Zentrumsversorgung << Allgemeine Krankenhäuser
# 0                              5784342                     8810061
# 1                              5825193                     8823084
# 2                              5846935                     8672308
# 3                              6570401                     8629169
# 4                              6620331                     8701451
#
# [5 rows x 30 columns]

# %%
df_services_melt.head()
# Out:
#                 Region_ID   Region  Jahr    Anzahl_Spitaeler  \
# Krankenhaus_Typ                          ....Grundversorgung
# 0                    8100  Schweiz  2010                  91
# 1                    8100  Schweiz  2011                  90
# 2                    8100  Schweiz  2012                  86
# 3                    8100  Schweiz  2013                  74
# 4                    8100  Schweiz  2014                  69
#
#                                                                     \
# Krankenhaus_Typ ....Zentrumsversorgung << Allgemeine Krankenhäuser
# 0                                   30                         121
# 1                                   30                         120
# 2                                   30                         116
# 3                                   39                         113
# 4                                   39                         108
#
#                        Betten_Total                         \
# Krankenhaus_Typ ....Grundversorgung ....Zentrumsversorgung
# 0                              9085                  17031
# 1                              8940                  17124
# 2                              8693                  17171
# 3                              6241                  18824
# 4                              6237                  18666
#
#                                                     Betten_akut  ...  \
# Krankenhaus_Typ << Allgemeine Krankenhäuser ....Grundversorgung  ...
# 0                                     26116                8439  ...
# 1                                     26064                8259  ...
# 2                                     25864                7953  ...
# 3                                     25065                5576  ...
# 4                                     24903                5519  ...
#
#                                 Betten_reha      Bettenbelegung  \
# Krankenhaus_Typ << Allgemeine Krankenhäuser ....Grundversorgung
# 0                                      2542                  91
# 1                                      2751                  92
# 2                                      2457                  89
# 3                                      2160                  90
# 4                                      2135                  91
#
#                                                                     \
# Krankenhaus_Typ ....Zentrumsversorgung << Allgemeine Krankenhäuser
# 0                                   93                          92
# 1                                   93                          93
# 2                                   93                          92
# 3                                   96                          94
# 4                                   97                          96
#
#                  Bettenbetriebstage                         \
# Krankenhaus_Typ ....Grundversorgung ....Zentrumsversorgung
# 0                           3315849                6216484
# 1                           3262957                6250270
# 2                           3181754                6284578
# 3                           2278028                6870815
# 4                           2276615                6812962
#
#                                                Pflegetage_M_365  \
# Krankenhaus_Typ << Allgemeine Krankenhäuser ....Grundversorgung
# 0                                   9532333             3025719
# 1                                   9513227             2997891
# 2                                   9466332             2825373
# 3                                   9148843             2058768
# 4                                   9089577             2081120
#
#
# Krankenhaus_Typ ....Zentrumsversorgung << Allgemeine Krankenhäuser
# 0                              5784342                     8810061
# 1                              5825193                     8823084
# 2                              5846935                     8672308
# 3                              6570401                     8629169
# 4                              6620331                     8701451
#
# [5 rows x 30 columns]

# %%
###renaming the columns to get a better oversight and information
df_services_melt.columns = ["Region_ID", "Region", "Jahr", "Anzahl_Spitaeler_GrVe", "Anzahl_Spitaeler_ZeVe", "Anzahl_Spitaeler_AllgKr",
    "Betten_Total_GrVe", "Betten_Total_ZeVe", "Betten_Total_AllgKr", "Betten_akut_GrVe", "Betten_akut_ZeVe", "Betten_akut_AllgKr",
    "Betten_geb_GrVe", "Betten_geb_ZeVe", "Betten_geb_AllgKr", "Betten_psy_GrVe", "Betten_psy_ZeVe", "Betten_psy_AllgKr",
    "Betten_reha_GrVe", "Betten_reha_ZeVe", "Betten_reha_AllgKr", "Bettenbelegung_GrVe", "Bettenbelegung_ZeVe", "Bettenbelegung_AllgKr",
    "Bettenbetriebstage_GrVe", "Bettenbetriebstage_ZeVe", "Bettenbetriebstage_AllgKr", "Pflegetage_M_365_GrVe", "Pflegetage_M_365_ZeVe", "Pflegetage_M_365_AllgKr"]

df_services_melt.head()
# Out:
#   Region_ID   Region  Jahr Anzahl_Spitaeler_GrVe Anzahl_Spitaeler_ZeVe  \
# 0      8100  Schweiz  2010                    91                    30
# 1      8100  Schweiz  2011                    90                    30
# 2      8100  Schweiz  2012                    86                    30
# 3      8100  Schweiz  2013                    74                    39
# 4      8100  Schweiz  2014                    69                    39
#
#   Anzahl_Spitaeler_AllgKr Betten_Total_GrVe Betten_Total_ZeVe  \
# 0                     121              9085             17031
# 1                     120              8940             17124
# 2                     116              8693             17171
# 3                     113              6241             18824
# 4                     108              6237             18666
#
#   Betten_Total_AllgKr Betten_akut_GrVe  ... Betten_reha_AllgKr  \
# 0               26116             8439  ...               2542
# 1               26064             8259  ...               2751
# 2               25864             7953  ...               2457
# 3               25065             5576  ...               2160
# 4               24903             5519  ...               2135
#
#   Bettenbelegung_GrVe Bettenbelegung_ZeVe Bettenbelegung_AllgKr  \
# 0                  91                  93                    92
# 1                  92                  93                    93
# 2                  89                  93                    92
# 3                  90                  96                    94
# 4                  91                  97                    96
#
#   Bettenbetriebstage_GrVe Bettenbetriebstage_ZeVe Bettenbetriebstage_AllgKr  \
# 0                 3315849                 6216484                   9532333
# 1                 3262957                 6250270                   9513227
# 2                 3181754                 6284578                   9466332
# 3                 2278028                 6870815                   9148843
# 4                 2276615                 6812962                   9089577
#
#   Pflegetage_M_365_GrVe Pflegetage_M_365_ZeVe Pflegetage_M_365_AllgKr
# 0               3025719               5784342                 8810061
# 1               2997891               5825193                 8823084
# 2               2825373               5846935                 8672308
# 3               2058768               6570401                 8629169
# 4               2081120               6620331                 8701451
#
# [5 rows x 30 columns]

# %% [markdown]
# 2. Tidying df_infrastructure so every "Gerät" and "Untersuchungen_Gerät" is a single column

# %%
###dropping the Gerät_Beschreibung, created a new cell above, initially i did this in the pivoting sector below but than i cant run the code again because it gives an error the column doesnst exist anymore
df_infrastructure_melt = df_infrastructure_melt.drop(columns=["Gerät_Beschreibung"])

# %%
df_infrastructure_melt = df_infrastructure_melt.sort_values(by=["Jahr", "Region_ID"])
df_infrastructure_melt.head(10)


###changing Gerät_Untersuchungen and Anzahl_Gerät to a column so we have one line per year and region
df_infrastructure_melt = df_infrastructure_melt.pivot(index=["Region_ID", "Region", "Jahr"], columns="Gerät_Kurzname", values=["Anzahl_Infra", "Untersuchungen_Total"]).reset_index()
df_infrastructure_melt.head(20)

###renaming the columns
df_infrastructure_melt.columns = ["Region_ID", "Region", "Jahr", "ANGIOGRAPHIE_Geräte", "CT_SCANNER_Geräte", "DIALYSE_Geräte", "GAMMA_CAMERA_Geräte", "LINEARBESCHLEUNIGER_Geräte", "LITHOTRIPTOR_Geräte",
                                  "MRI_Geräte", "PET_SCANNER_Geräte", "ANGIOGRAPHIE_Untersuchungen", "CT_SCANNER_Untersuchungen", "DIALYSE_Untersuchungen", "GAMMA_CAMERA_Untersuchungen", "LINEARBESCHLEUNIGER_Untersuchungen",
                                  "LITHOTRIPTOR_Untersuchungen", "MRI_Untersuchungen", "PET_SCANNER_Untersuchungen"]
df_infrastructure_melt.head(20)
# Out:
#    Region_ID            Region  Jahr  ANGIOGRAPHIE_Geräte  CT_SCANNER_Geräte  \
# 0       8100           Schweiz  2013                  137                194
# 1       8100           Schweiz  2014                  138                201
# 2       8100           Schweiz  2015                  146                201
# 3       8100           Schweiz  2016                  143                205
# 4       8100           Schweiz  2017                  136                211
# 5       8100           Schweiz  2018                  136                217
# 6       8100           Schweiz  2019                  128                219
# 7       8100           Schweiz  2020                  141                226
# 8       8100           Schweiz  2021                  145                228
# 9       8100           Schweiz  2022                  154                236
# 10      8100           Schweiz  2023                  152                235
# 11         A  Région lémanique  2013                   28                 41
# 12         A  Région lémanique  2014                   29                 38
# 13         A  Région lémanique  2015                   29                 38
# 14         A  Région lémanique  2016                   26                 39
# 15         A  Région lémanique  2017                   25                 41
# 16         A  Région lémanique  2018                   27                 44
# 17         A  Région lémanique  2019                   23                 41
# 18         A  Région lémanique  2020                   24                 42
# 19         A  Région lémanique  2021                   23                 45
#
#     DIALYSE_Geräte  GAMMA_CAMERA_Geräte  LINEARBESCHLEUNIGER_Geräte  \
# 0             1141                   68                          52
# 1             1142                   65                          57
# 2             1152                   64                          57
# 3             1182                   63                          57
# 4             1225                   62                          57
# 5             1257                   64                          60
# 6             1279                   61                          62
# 7             1329                   64                          67
# 8             1330                   64                          68
# 9             1331                   65                          70
# 10            1348                   66                          70
# 11             247                   16                          13
# 12             246                   13                          13
# 13             243                   13                          14
# 14             241                   13                          13
# 15             233                   12                          13
# 16             231                   14                          15
# 17             238                   11                          15
# 18             241                   13                          18
# 19             235                   13                          19
#
#     LITHOTRIPTOR_Geräte  MRI_Geräte  PET_SCANNER_Geräte  \
# 0                    34         162                  28
# 1                    37         172                  29
# 2                    34         183                  28
# 3                    32         188                  28
# 4                    31         197                  28
# 5                    31         207                  32
# 6                    30         215                  33
# 7                    30         221                  34
# 8                    30         224                  37
# 9                    29         239                  39
# 10                   27         241                  41
# 11                    6          34                   8
# 12                    6          36                   7
# 13                    6          40                   6
# 14                    6          43                   6
# 15                    6          45                   6
# 16                    7          48                  10
# 17                    6          49                   9
# 18                    6          49                  10
# 19                    6          50                  10
#
#     ANGIOGRAPHIE_Untersuchungen  CT_SCANNER_Untersuchungen  \
# 0                        105713                     730432
# 1                        116967                     804455
# 2                        119395                     830373
# 3                        121854                     870914
# 4                        118025                     928960
# 5                        120937                     970164
# 6                        122241                    1034229
# 7                        125604                    1052045
# 8                        130066                    1178655
# 9                        127667                    1242782
# 10                       124086                    1242095
# 11                        21146                     145536
# 12                        20809                     161700
# 13                        23177                     169888
# 14                        21851                     176268
# 15                        23531                     198018
# 16                        24294                     193700
# 17                        23156                     195400
# 18                        25644                     207132
# 19                        23962                     215321
#
#     DIALYSE_Untersuchungen  GAMMA_CAMERA_Untersuchungen  \
# 0                   383943                        98765
# 1                   411329                        92719
# 2                   428160                       113005
# 3                   424402                        98821
# 4                   430398                        91661
# 5                   437222                        96631
# 6                   447825                       119658
# 7                   450923                       100244
# 8                   446944                       103749
# 9                   451473                        99496
# 10                  456529                        94929
# 11                   88598                        14245
# 12                   93094                        13156
# 13                   91990                        15348
# 14                   78338                        10447
# 15                   84468                        10387
# 16                   86122                        13745
# 17                   92963                        12595
# 18                   87782                        14904
# 19                   80789                        16180
#
#     LINEARBESCHLEUNIGER_Untersuchungen  LITHOTRIPTOR_Untersuchungen  \
# 0                               334002                         6061
# 1                               321444                         6845
# 2                               313595                         6370
# 3                               325026                         5714
# 4                               327413                         5703
# 5                               354576                         6262
# 6                               343013                         5348
# 7                               366821                         3064
# 8                               374427                         2970
# 9                               379014                         2274
# 10                              399087                         2130
# 11                               71853                         1266
# 12                               83292                         1392
# 13                               85858                         1431
# 14                               75645                         1306
# 15                               73912                         1310
# 16                               90963                         1333
# 17                               80827                         1157
# 18                               89305                          775
# 19                               91576                          827
#
#     MRI_Untersuchungen  PET_SCANNER_Untersuchungen
# 0               489717                       31741
# 1               537774                       34318
# 2               578652                       34085
# 3               604485                       40403
# 4               626538                       45165
# 5               662580                       50382
# 6               696231                       53960
# 7               677057                       58379
# 8               770099                       65246
# 9               801749                       76491
# 10              816419                       79800
# 11               86317                        8061
# 12              100240                        8223
# 13              106805                        9046
# 14              115361                        9447
# 15              119199                       11060
# 16              126636                       11730
# 17              126684                       12149
# 18              128838                       15016
# 19              143202                       16408

# %% [markdown]
# 3. Tidying staff

# %%
df_staff_melt = df_staff_melt.sort_values(by=["Jahr", "Region_ID"])
df_staff_melt.head()
# Out:
#     Berufsgruppe_ID       Berufsgruppe  Krankenhaus_Typ_ID  \
# 0               1.0     << Ärzteschaft                12.0
# 8               1.0     << Ärzteschaft                 1.0
# 16              1.0     << Ärzteschaft                 2.0
# 24              8.0  << Pflegepersonal                12.0
# 32              8.0  << Pflegepersonal                 1.0
#
#                 Krankenhaus_Typ Region_ID   Region  Jahr  Anzahl VZÄ
# 0   << Allgemeine Krankenhäuser      8100  Schweiz  2010    15723.60
# 8        ....Zentrumsversorgung      8100  Schweiz  2010    12154.95
# 16          ....Grundversorgung      8100  Schweiz  2010     3568.65
# 24  << Allgemeine Krankenhäuser      8100  Schweiz  2010    47591.48
# 32       ....Zentrumsversorgung      8100  Schweiz  2010    32955.09

# %%
###dropping Berufsgruppe_ID
df_staff_melt = df_staff_melt.drop(columns=["Berufsgruppe_ID", "Krankenhaus_Typ_ID"])
df_staff_melt.head()
# Out:
#          Berufsgruppe              Krankenhaus_Typ Region_ID   Region  Jahr  \
# 0      << Ärzteschaft  << Allgemeine Krankenhäuser      8100  Schweiz  2010
# 8      << Ärzteschaft       ....Zentrumsversorgung      8100  Schweiz  2010
# 16     << Ärzteschaft          ....Grundversorgung      8100  Schweiz  2010
# 24  << Pflegepersonal  << Allgemeine Krankenhäuser      8100  Schweiz  2010
# 32  << Pflegepersonal       ....Zentrumsversorgung      8100  Schweiz  2010
#
#     Anzahl VZÄ
# 0     15723.60
# 8     12154.95
# 16     3568.65
# 24    47591.48
# 32    32955.09

# %%
###changing the different Berufsgruppen to different columns
df_staff_melt = df_staff_melt.pivot(index=["Krankenhaus_Typ", "Region_ID", "Region", "Jahr"], columns="Berufsgruppe", values="Anzahl VZÄ").reset_index()
df_staff_melt.head()
# Out:
# Berufsgruppe      Krankenhaus_Typ Region_ID   Region  Jahr  \
# 0             ....Grundversorgung      8100  Schweiz  2010
# 1             ....Grundversorgung      8100  Schweiz  2011
# 2             ....Grundversorgung      8100  Schweiz  2012
# 3             ....Grundversorgung      8100  Schweiz  2013
# 4             ....Grundversorgung      8100  Schweiz  2014
#
# Berufsgruppe  << Medizinisch - technisches Personal  \
# 0                                           3556.61
# 1                                           3458.05
# 2                                           3294.98
# 3                                           2358.83
# 4                                           2194.96
#
# Berufsgruppe  << Medizinisch - therapeutisches Personal  << Pflegepersonal  \
# 0                                               1104.33           14636.39
# 1                                               1069.25           14319.46
# 2                                               1058.45           14046.32
# 3                                                890.91           10710.22
# 4                                                936.47           11216.52
#
# Berufsgruppe  << Ärzteschaft
# 0                    3568.65
# 1                    3608.74
# 2                    3483.40
# 3                    2588.36
# 4                    2725.99

# %%
###rename the columns
df_staff_melt.columns = ["Krankenhaus_Typ", "Region_ID", "Region", "Jahr", "MedTechPersonal_Anz", "MedTheraPersonal_Anz", "Pflegepersonal_Anz", "Ärzteschaft_Anz"]
df_staff_melt.head()
# Out:
#        Krankenhaus_Typ Region_ID   Region  Jahr  MedTechPersonal_Anz  \
# 0  ....Grundversorgung      8100  Schweiz  2010              3556.61
# 1  ....Grundversorgung      8100  Schweiz  2011              3458.05
# 2  ....Grundversorgung      8100  Schweiz  2012              3294.98
# 3  ....Grundversorgung      8100  Schweiz  2013              2358.83
# 4  ....Grundversorgung      8100  Schweiz  2014              2194.96
#
#    MedTheraPersonal_Anz  Pflegepersonal_Anz  Ärzteschaft_Anz
# 0               1104.33            14636.39          3568.65
# 1               1069.25            14319.46          3608.74
# 2               1058.45            14046.32          3483.40
# 3                890.91            10710.22          2588.36
# 4                936.47            11216.52          2725.99

# %%
###as for services, differ between the Krankenhaus_Typen
df_staff_melt = df_staff_melt.pivot(index=["Region_ID", "Region", "Jahr"], columns="Krankenhaus_Typ", values=["MedTechPersonal_Anz", "MedTheraPersonal_Anz", "Pflegepersonal_Anz", "Ärzteschaft_Anz"]).reset_index()
df_staff_melt.head()
# Out:
#                 Region_ID   Region  Jahr MedTechPersonal_Anz  \
# Krankenhaus_Typ                          ....Grundversorgung
# 0                    8100  Schweiz  2010             3556.61
# 1                    8100  Schweiz  2011             3458.05
# 2                    8100  Schweiz  2012             3294.98
# 3                    8100  Schweiz  2013             2358.83
# 4                    8100  Schweiz  2014             2194.96
#
#                                                                     \
# Krankenhaus_Typ ....Zentrumsversorgung << Allgemeine Krankenhäuser
# 0                              7200.44                    10757.05
# 1                              7617.76                    11075.81
# 2                              7897.32                    11192.30
# 3                              8379.71                    10738.54
# 4                              8548.09                    10743.05
#
#                 MedTheraPersonal_Anz                         \
# Krankenhaus_Typ  ....Grundversorgung ....Zentrumsversorgung
# 0                            1104.33                2377.39
# 1                            1069.25                2456.84
# 2                            1058.45                2700.40
# 3                             890.91                2981.75
# 4                             936.47                3083.09
#
#                                              Pflegepersonal_Anz  \
# Krankenhaus_Typ << Allgemeine Krankenhäuser ....Grundversorgung
# 0                                   3481.72            14636.39
# 1                                   3526.09            14319.46
# 2                                   3758.85            14046.32
# 3                                   3872.66            10710.22
# 4                                   4019.56            11216.52
#
#                                                                     \
# Krankenhaus_Typ ....Zentrumsversorgung << Allgemeine Krankenhäuser
# 0                             32955.09                    47591.48
# 1                             33384.39                    47703.85
# 2                             34602.52                    48648.84
# 3                             39254.60                    49964.82
# 4                             40307.35                    51523.87
#
#                     Ärzteschaft_Anz                         \
# Krankenhaus_Typ ....Grundversorgung ....Zentrumsversorgung
# 0                           3568.65               12154.95
# 1                           3608.74               12851.99
# 2                           3483.40               13212.17
# 3                           2588.36               14364.39
# 4                           2725.99               14799.93
#
#
# Krankenhaus_Typ << Allgemeine Krankenhäuser
# 0                                  15723.60
# 1                                  16460.73
# 2                                  16695.57
# 3                                  16952.75
# 4                                  17525.92

# %%
###rename the columns
df_staff_melt.columns = ["Region_ID", "Region", "Jahr", "MedTechPersonal_Anz_GrVe", "MedTechPersonal_Anz_ZeVe", "MedTechPersonal_Anz_AllgKr",
    "MedTheraPersonal_Anz_GrVe", "MedTheraPersonal_Anz_ZeVe", "MedTheraPersonal_Anz_AllgKr", "Pflegepersonal_Anz_GrVe", "Pflegepersonal_Anz_ZeVe", "Pflegepersonal_Anz_AllgKr",
    "Ärzteschaft_Anz_GrVe", "Ärzteschaft_Anz_ZeVe", "Ärzteschaft_Anz_AllgKr"]

df_staff_melt.head()
# Out:
#   Region_ID   Region  Jahr  MedTechPersonal_Anz_GrVe  \
# 0      8100  Schweiz  2010                   3556.61
# 1      8100  Schweiz  2011                   3458.05
# 2      8100  Schweiz  2012                   3294.98
# 3      8100  Schweiz  2013                   2358.83
# 4      8100  Schweiz  2014                   2194.96
#
#    MedTechPersonal_Anz_ZeVe  MedTechPersonal_Anz_AllgKr  \
# 0                   7200.44                    10757.05
# 1                   7617.76                    11075.81
# 2                   7897.32                    11192.30
# 3                   8379.71                    10738.54
# 4                   8548.09                    10743.05
#
#    MedTheraPersonal_Anz_GrVe  MedTheraPersonal_Anz_ZeVe  \
# 0                    1104.33                    2377.39
# 1                    1069.25                    2456.84
# 2                    1058.45                    2700.40
# 3                     890.91                    2981.75
# 4                     936.47                    3083.09
#
#    MedTheraPersonal_Anz_AllgKr  Pflegepersonal_Anz_GrVe  \
# 0                      3481.72                 14636.39
# 1                      3526.09                 14319.46
# 2                      3758.85                 14046.32
# 3                      3872.66                 10710.22
# 4                      4019.56                 11216.52
#
#    Pflegepersonal_Anz_ZeVe  Pflegepersonal_Anz_AllgKr  Ärzteschaft_Anz_GrVe  \
# 0                 32955.09                   47591.48               3568.65
# 1                 33384.39                   47703.85               3608.74
# 2                 34602.52                   48648.84               3483.40
# 3                 39254.60                   49964.82               2588.36
# 4                 40307.35                   51523.87               2725.99
#
#    Ärzteschaft_Anz_ZeVe  Ärzteschaft_Anz_AllgKr
# 0              12154.95                15723.60
# 1              12851.99                16460.73
# 2              13212.17                16695.57
# 3              14364.39                16952.75
# 4              14799.93                17525.92

# %% [markdown]
# Getting again an overview of all datasets and seeing if theyre ready to merge

# %%
df_services_melt.head()
# Out:
#   Region_ID   Region  Jahr Anzahl_Spitaeler_GrVe Anzahl_Spitaeler_ZeVe  \
# 0      8100  Schweiz  2010                    91                    30
# 1      8100  Schweiz  2011                    90                    30
# 2      8100  Schweiz  2012                    86                    30
# 3      8100  Schweiz  2013                    74                    39
# 4      8100  Schweiz  2014                    69                    39
#
#   Anzahl_Spitaeler_AllgKr Betten_Total_GrVe Betten_Total_ZeVe  \
# 0                     121              9085             17031
# 1                     120              8940             17124
# 2                     116              8693             17171
# 3                     113              6241             18824
# 4                     108              6237             18666
#
#   Betten_Total_AllgKr Betten_akut_GrVe  ... Betten_reha_AllgKr  \
# 0               26116             8439  ...               2542
# 1               26064             8259  ...               2751
# 2               25864             7953  ...               2457
# 3               25065             5576  ...               2160
# 4               24903             5519  ...               2135
#
#   Bettenbelegung_GrVe Bettenbelegung_ZeVe Bettenbelegung_AllgKr  \
# 0                  91                  93                    92
# 1                  92                  93                    93
# 2                  89                  93                    92
# 3                  90                  96                    94
# 4                  91                  97                    96
#
#   Bettenbetriebstage_GrVe Bettenbetriebstage_ZeVe Bettenbetriebstage_AllgKr  \
# 0                 3315849                 6216484                   9532333
# 1                 3262957                 6250270                   9513227
# 2                 3181754                 6284578                   9466332
# 3                 2278028                 6870815                   9148843
# 4                 2276615                 6812962                   9089577
#
#   Pflegetage_M_365_GrVe Pflegetage_M_365_ZeVe Pflegetage_M_365_AllgKr
# 0               3025719               5784342                 8810061
# 1               2997891               5825193                 8823084
# 2               2825373               5846935                 8672308
# 3               2058768               6570401                 8629169
# 4               2081120               6620331                 8701451
#
# [5 rows x 30 columns]

# %%
df_staff_melt.head()
# Out:
#   Region_ID   Region  Jahr  MedTechPersonal_Anz_GrVe  \
# 0      8100  Schweiz  2010                   3556.61
# 1      8100  Schweiz  2011                   3458.05
# 2      8100  Schweiz  2012                   3294.98
# 3      8100  Schweiz  2013                   2358.83
# 4      8100  Schweiz  2014                   2194.96
#
#    MedTechPersonal_Anz_ZeVe  MedTechPersonal_Anz_AllgKr  \
# 0                   7200.44                    10757.05
# 1                   7617.76                    11075.81
# 2                   7897.32                    11192.30
# 3                   8379.71                    10738.54
# 4                   8548.09                    10743.05
#
#    MedTheraPersonal_Anz_GrVe  MedTheraPersonal_Anz_ZeVe  \
# 0                    1104.33                    2377.39
# 1                    1069.25                    2456.84
# 2                    1058.45                    2700.40
# 3                     890.91                    2981.75
# 4                     936.47                    3083.09
#
#    MedTheraPersonal_Anz_AllgKr  Pflegepersonal_Anz_GrVe  \
# 0                      3481.72                 14636.39
# 1                      3526.09                 14319.46
# 2                      3758.85                 14046.32
# 3                      3872.66                 10710.22
# 4                      4019.56                 11216.52
#
#    Pflegepersonal_Anz_ZeVe  Pflegepersonal_Anz_AllgKr  Ärzteschaft_Anz_GrVe  \
# 0                 32955.09                   47591.48               3568.65
# 1                 33384.39                   47703.85               3608.74
# 2                 34602.52                   48648.84               3483.40
# 3                 39254.60                   49964.82               2588.36
# 4                 40307.35                   51523.87               2725.99
#
#    Ärzteschaft_Anz_ZeVe  Ärzteschaft_Anz_AllgKr
# 0              12154.95                15723.60
# 1              12851.99                16460.73
# 2              13212.17                16695.57
# 3              14364.39                16952.75
# 4              14799.93                17525.92

# %%
df_infrastructure_melt.head()
# Out:
#   Region_ID   Region  Jahr  ANGIOGRAPHIE_Geräte  CT_SCANNER_Geräte  \
# 0      8100  Schweiz  2013                  137                194
# 1      8100  Schweiz  2014                  138                201
# 2      8100  Schweiz  2015                  146                201
# 3      8100  Schweiz  2016                  143                205
# 4      8100  Schweiz  2017                  136                211
#
#    DIALYSE_Geräte  GAMMA_CAMERA_Geräte  LINEARBESCHLEUNIGER_Geräte  \
# 0            1141                   68                          52
# 1            1142                   65                          57
# 2            1152                   64                          57
# 3            1182                   63                          57
# 4            1225                   62                          57
#
#    LITHOTRIPTOR_Geräte  MRI_Geräte  PET_SCANNER_Geräte  \
# 0                   34         162                  28
# 1                   37         172                  29
# 2                   34         183                  28
# 3                   32         188                  28
# 4                   31         197                  28
#
#    ANGIOGRAPHIE_Untersuchungen  CT_SCANNER_Untersuchungen  \
# 0                       105713                     730432
# 1                       116967                     804455
# 2                       119395                     830373
# 3                       121854                     870914
# 4                       118025                     928960
#
#    DIALYSE_Untersuchungen  GAMMA_CAMERA_Untersuchungen  \
# 0                  383943                        98765
# 1                  411329                        92719
# 2                  428160                       113005
# 3                  424402                        98821
# 4                  430398                        91661
#
#    LINEARBESCHLEUNIGER_Untersuchungen  LITHOTRIPTOR_Untersuchungen  \
# 0                              334002                         6061
# 1                              321444                         6845
# 2                              313595                         6370
# 3                              325026                         5714
# 4                              327413                         5703
#
#    MRI_Untersuchungen  PET_SCANNER_Untersuchungen
# 0              489717                       31741
# 1              537774                       34318
# 2              578652                       34085
# 3              604485                       40403
# 4              626538                       45165

# %%
df_cost_ready.head()
# Out:
#     Jahr             Region      KostAmbA     KostStatA
# 0   2010  Espace Mittelland  1.003112e+09  2.687294e+09
# 1   2010    Nordwestschweiz  7.039205e+08  1.632927e+09
# 2   2010         Ostschweiz  4.827668e+08  1.504621e+09
# 3   2010   Région lémanique  9.297511e+08  2.268943e+09
# 98  2010            Schweiz  4.498723e+09  1.207283e+10

# %%
### deleting the region_ids in all datsets before merging
df_services_melt = df_services_melt.drop(columns=["Region_ID"])
df_staff_melt = df_staff_melt.drop(columns=["Region_ID"])
df_infrastructure_melt = df_infrastructure_melt.drop(columns=["Region_ID"])

# %%
###lets get ready to MMMMEEEEEERRRGGGGGEEEEEEE
###df_health = (
    #df_cost_ready
    #.merge(df_services_melt, on=["Jahr", "Region"], how = "left")
    #.merge(df_staff_melt, on=["Jahr", "Region"], how = "left")
    #.merge(df_infrastructure_melt, on=["Jahr", "Region"], how = "left"))

###df_health.head(10)

# %% [markdown]
# we had an error due to a concatinating issue with integer and strings

# %%
print(df_cost_ready["Jahr"].dtype)
print(df_services_melt["Jahr"].dtype)
print(df_staff_melt["Jahr"].dtype)
print(df_infrastructure_melt["Jahr"].dtype)

###in cost the year is an integer in the other datasets an object, therefore changing all to integers
df_services_melt["Jahr"] = df_services_melt["Jahr"].astype(int)
df_staff_melt["Jahr"] = df_staff_melt["Jahr"].astype(int)
df_infrastructure_melt["Jahr"] = df_infrastructure_melt["Jahr"].astype(int)
# Out:
# int64
# object
# object
# object

# %%
###lets get ready to MMMMEEEEEERRRGGGGGEEEEEEE
df_health = (
    df_cost_ready
    .merge(df_services_melt, on=["Jahr", "Region"], how = "left")
    .merge(df_staff_melt, on=["Jahr", "Region"], how = "left")
    .merge(df_infrastructure_melt, on=["Jahr", "Region"], how = "left"))

df_health.head(50)
# Out:
#     Jahr             Region      KostAmbA     KostStatA Anzahl_Spitaeler_GrVe  \
# 0   2010  Espace Mittelland  1.003112e+09  2.687294e+09                    14
# 1   2010    Nordwestschweiz  7.039205e+08  1.632927e+09                    10
# 2   2010         Ostschweiz  4.827668e+08  1.504621e+09                    20
# 3   2010   Région lémanique  9.297511e+08  2.268943e+09                    16
# 4   2010            Schweiz  4.498723e+09  1.207283e+10                    91
# 5   2010             Ticino  2.009135e+08  5.616815e+08                     7
# 6   2010     Zentralschweiz  3.793588e+08  8.476163e+08                    10
# 7   2010             Zürich  7.989004e+08  2.569751e+09                    14
# 8   2011  Espace Mittelland  1.066570e+09  2.732638e+09                    14
# 9   2011    Nordwestschweiz  7.618842e+08  1.866077e+09                    10
# 10  2011         Ostschweiz  5.105224e+08  1.522177e+09                    20
# 11  2011   Région lémanique  1.014783e+09  2.336530e+09                    16
# 12  2011            Schweiz  4.849648e+09  1.252642e+10                    90
# 13  2011             Ticino  2.087272e+08  5.821723e+08                     7
# 14  2011     Zentralschweiz  4.190165e+08  8.786632e+08                    10
# 15  2011             Zürich  8.681449e+08  2.608159e+09                    13
# 16  2012  Espace Mittelland  1.148330e+09  2.830355e+09                    12
# 17  2012    Nordwestschweiz  8.537332e+08  2.004920e+09                     9
# 18  2012         Ostschweiz  6.007304e+08  1.699792e+09                    19
# 19  2012   Région lémanique  1.061885e+09  2.469713e+09                    16
# 20  2012            Schweiz  5.269642e+09  1.327163e+10                    86
# 21  2012             Ticino  2.207646e+08  5.849642e+08                     7
# 22  2012     Zentralschweiz  4.402176e+08  9.088554e+08                    10
# 23  2012             Zürich  9.439814e+08  2.773029e+09                    13
# 24  2013  Espace Mittelland  1.203153e+09  2.898136e+09                    11
# 25  2013    Nordwestschweiz  9.028237e+08  2.099570e+09                     9
# 26  2013         Ostschweiz  6.277036e+08  1.780539e+09                    18
# 27  2013   Région lémanique  1.169329e+09  2.526152e+09                    14
# 28  2013            Schweiz  5.614162e+09  1.378030e+10                    74
# 29  2013             Ticino  2.380298e+08  6.099715e+08                     7
# 30  2013     Zentralschweiz  4.792873e+08  9.870043e+08                     8
# 31  2013             Zürich  9.938361e+08  2.878924e+09                     7
# 32  2014  Espace Mittelland  1.185705e+09  2.994803e+09                    10
# 33  2014    Nordwestschweiz  9.602761e+08  2.165646e+09                     8
# 34  2014         Ostschweiz  6.817783e+08  1.868146e+09                    18
# 35  2014   Région lémanique  1.312437e+09  2.639640e+09                    12
# 36  2014            Schweiz  5.922281e+09  1.434392e+10                    69
# 37  2014             Ticino  2.521468e+08  6.267246e+08                     7
# 38  2014     Zentralschweiz  5.034852e+08  1.025643e+09                     7
# 39  2014             Zürich  1.026453e+09  3.023319e+09                     7
# 40  2015  Espace Mittelland  1.288557e+09  3.022692e+09                     9
# 41  2015    Nordwestschweiz  9.539791e+08  2.190644e+09                     8
# 42  2015         Ostschweiz  7.176086e+08  1.890787e+09                    17
# 43  2015   Région lémanique  1.349602e+09  2.740957e+09                    12
# 44  2015            Schweiz  6.185046e+09  1.464289e+10                    66
# 45  2015             Ticino  2.578075e+08  6.403629e+08                     7
# 46  2015     Zentralschweiz  5.092854e+08  1.035560e+09                     7
# 47  2015             Zürich  1.108205e+09  3.121889e+09                     6
# 48  2016  Espace Mittelland  1.383170e+09  3.061593e+09                     7
# 49  2016    Nordwestschweiz  1.086152e+09  2.224676e+09                     7
#
#    Anzahl_Spitaeler_ZeVe Anzahl_Spitaeler_AllgKr Betten_Total_GrVe  \
# 0                      8                      22              1610
# 1                      5                      15              1059
# 2                      3                      23              1557
# 3                      7                      23              1696
# 4                     30                     121              9085
# 5                      1                       8                 X
# 6                      1                      11                 X
# 7                      5                      19              1726
# 8                      8                      22              1570
# 9                      5                      15              1077
# 10                     3                      23              1515
# 11                     7                      23              1674
# 12                    30                     120              8940
# 13                     1                       8                 X
# 14                     1                      11                 X
# 15                     5                      18              1728
# 16                     9                      21              1348
# 17                     4                      13              1019
# 18                     3                      22              1414
# 19                     7                      23              1831
# 20                    30                     116              8693
# 21                     1                       8                 X
# 22                     1                      11                 X
# 23                     5                      18              1720
# 24                     9                      20              1197
# 25                     6                      15               640
# 26                     4                      22              1142
# 27                     5                      19              1642
# 28                    39                     113              6241
# 29                     1                       8                 X
# 30                     3                      11               545
# 31                    11                      18               577
# 32                     9                      19              1151
# 33                     6                      14               666
# 34                     4                      22              1133
# 35                     5                      17              1677
# 36                    39                     108              6237
# 37                     1                       8                 X
# 38                     3                      10               541
# 39                    11                      18               572
# 40                    10                      19              1043
# 41                     6                      14               677
# 42                     4                      21              1099
# 43                     5                      17              1737
# 44                    40                     106              6118
# 45                     1                       8                 X
# 46                     3                      10               549
# 47                    11                      17               515
# 48                    11                      18               754
# 49                     6                      13               642
#
#    Betten_Total_ZeVe Betten_Total_AllgKr  ... MRI_Geräte PET_SCANNER_Geräte  \
# 0               3943                5553  ...        NaN                NaN
# 1               2372                3431  ...        NaN                NaN
# 2               1687                3244  ...        NaN                NaN
# 3               4862                6559  ...        NaN                NaN
# 4              17031               26116  ...        NaN                NaN
# 5                  X                1446  ...        NaN                NaN
# 6                  X                1771  ...        NaN                NaN
# 7               2386                4112  ...        NaN                NaN
# 8               3943                5513  ...        NaN                NaN
# 9               2303                3380  ...        NaN                NaN
# 10              1667                3182  ...        NaN                NaN
# 11              5053                6727  ...        NaN                NaN
# 12             17124               26064  ...        NaN                NaN
# 13                 X                1418  ...        NaN                NaN
# 14                 X                1719  ...        NaN                NaN
# 15              2396                4125  ...        NaN                NaN
# 16              4254                5602  ...        NaN                NaN
# 17              2382                3400  ...        NaN                NaN
# 18              1657                3072  ...        NaN                NaN
# 19              4806                6638  ...        NaN                NaN
# 20             17171               25864  ...        NaN                NaN
# 21                 X                1428  ...        NaN                NaN
# 22                 X                1649  ...        NaN                NaN
# 23              2355                4075  ...        NaN                NaN
# 24              4317                5514  ...       36.0                5.0
# 25              2635                3275  ...       23.0                4.0
# 26              1946                3088  ...       20.0                3.0
# 27              4368                6011  ...       34.0                8.0
# 28             18824               25065  ...      162.0               28.0
# 29                 X                1446  ...        9.0                2.0
# 30              1146                1691  ...       13.0                1.0
# 31              3463                4041  ...       27.0                5.0
# 32              4127                5278  ...       41.0                5.0
# 33              2647                3313  ...       23.0                5.0
# 34              1981                3114  ...       21.0                3.0
# 35              4343                6020  ...       36.0                7.0
# 36             18666               24903  ...      172.0               29.0
# 37                 X                1450  ...        9.0                2.0
# 38              1151                1693  ...       14.0                2.0
# 39              3464                4035  ...       28.0                5.0
# 40              4239                5282  ...       43.0                5.0
# 41              2478                3155  ...       25.0                5.0
# 42              1956                3055  ...       21.0                3.0
# 43              4356                6093  ...       40.0                6.0
# 44             18601               24719  ...      183.0               28.0
# 45                 X                1443  ...        9.0                2.0
# 46              1146                1695  ...       16.0                2.0
# 47              3481                3996  ...       29.0                5.0
# 48              4349                5103  ...       44.0                5.0
# 49              2401                3043  ...       26.0                5.0
#
#    ANGIOGRAPHIE_Untersuchungen CT_SCANNER_Untersuchungen  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# 5                          NaN                       NaN
# 6                          NaN                       NaN
# 7                          NaN                       NaN
# 8                          NaN                       NaN
# 9                          NaN                       NaN
# 10                         NaN                       NaN
# 11                         NaN                       NaN
# 12                         NaN                       NaN
# 13                         NaN                       NaN
# 14                         NaN                       NaN
# 15                         NaN                       NaN
# 16                         NaN                       NaN
# 17                         NaN                       NaN
# 18                         NaN                       NaN
# 19                         NaN                       NaN
# 20                         NaN                       NaN
# 21                         NaN                       NaN
# 22                         NaN                       NaN
# 23                         NaN                       NaN
# 24                     24572.0                  123996.0
# 25                      7407.0                  103769.0
# 26                     16458.0                  103027.0
# 27                     21146.0                  145536.0
# 28                    105713.0                  730432.0
# 29                      7746.0                   54930.0
# 30                      2874.0                   46466.0
# 31                     25510.0                  152708.0
# 32                     24964.0                  150396.0
# 33                     11900.0                  104029.0
# 34                     16975.0                  116762.0
# 35                     20809.0                  161700.0
# 36                    116967.0                  804455.0
# 37                      7792.0                   65576.0
# 38                      2974.0                   50480.0
# 39                     31553.0                  155512.0
# 40                     27991.0                  149395.0
# 41                     10049.0                  107641.0
# 42                     17895.0                  118231.0
# 43                     23177.0                  169888.0
# 44                    119395.0                  830373.0
# 45                      7921.0                   63630.0
# 46                      3600.0                   54262.0
# 47                     28762.0                  167326.0
# 48                     28393.0                  155515.0
# 49                     10981.0                  114002.0
#
#    DIALYSE_Untersuchungen GAMMA_CAMERA_Untersuchungen  \
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN
# 5                     NaN                         NaN
# 6                     NaN                         NaN
# 7                     NaN                         NaN
# 8                     NaN                         NaN
# 9                     NaN                         NaN
# 10                    NaN                         NaN
# 11                    NaN                         NaN
# 12                    NaN                         NaN
# 13                    NaN                         NaN
# 14                    NaN                         NaN
# 15                    NaN                         NaN
# 16                    NaN                         NaN
# 17                    NaN                         NaN
# 18                    NaN                         NaN
# 19                    NaN                         NaN
# 20                    NaN                         NaN
# 21                    NaN                         NaN
# 22                    NaN                         NaN
# 23                    NaN                         NaN
# 24                87988.0                     10708.0
# 25                44483.0                     31721.0
# 26                46508.0                     11414.0
# 27                88598.0                     14245.0
# 28               383943.0                     98765.0
# 29                35196.0                      5259.0
# 30                33820.0                      3711.0
# 31                47350.0                     21707.0
# 32               100631.0                      9399.0
# 33                48416.0                     27669.0
# 34                46681.0                     11348.0
# 35                93094.0                     13156.0
# 36               411329.0                     92719.0
# 37                36897.0                      5261.0
# 38                36066.0                      5103.0
# 39                49544.0                     20783.0
# 40               103644.0                     10551.0
# 41                66385.0                     27399.0
# 42                46322.0                     13759.0
# 43                91990.0                     15348.0
# 44               428160.0                    113005.0
# 45                33884.0                      5087.0
# 46                34866.0                      7590.0
# 47                51069.0                     33271.0
# 48               104773.0                     10710.0
# 49                71462.0                     24767.0
#
#    LINEARBESCHLEUNIGER_Untersuchungen LITHOTRIPTOR_Untersuchungen  \
# 0                                 NaN                         NaN
# 1                                 NaN                         NaN
# 2                                 NaN                         NaN
# 3                                 NaN                         NaN
# 4                                 NaN                         NaN
# 5                                 NaN                         NaN
# 6                                 NaN                         NaN
# 7                                 NaN                         NaN
# 8                                 NaN                         NaN
# 9                                 NaN                         NaN
# 10                                NaN                         NaN
# 11                                NaN                         NaN
# 12                                NaN                         NaN
# 13                                NaN                         NaN
# 14                                NaN                         NaN
# 15                                NaN                         NaN
# 16                                NaN                         NaN
# 17                                NaN                         NaN
# 18                                NaN                         NaN
# 19                                NaN                         NaN
# 20                                NaN                         NaN
# 21                                NaN                         NaN
# 22                                NaN                         NaN
# 23                                NaN                         NaN
# 24                            53817.0                       843.0
# 25                            45149.0                      2386.0
# 26                            41943.0                       653.0
# 27                            71853.0                      1266.0
# 28                           334002.0                      6061.0
# 29                            18660.0                       249.0
# 30                            25306.0                       269.0
# 31                            77274.0                       395.0
# 32                            45381.0                      1012.0
# 33                            43944.0                      3279.0
# 34                            32210.0                       471.0
# 35                            83292.0                      1392.0
# 36                           321444.0                      6845.0
# 37                            13151.0                       200.0
# 38                            24435.0                       207.0
# 39                            79031.0                       284.0
# 40                            55556.0                      1054.0
# 41                            35213.0                      2851.0
# 42                            29076.0                       443.0
# 43                            85858.0                      1431.0
# 44                           313595.0                      6370.0
# 45                            14862.0                       188.0
# 46                            24852.0                       193.0
# 47                            68178.0                       210.0
# 48                            56263.0                      1092.0
# 49                            38584.0                      2390.0
#
#    MRI_Untersuchungen PET_SCANNER_Untersuchungen
# 0                 NaN                        NaN
# 1                 NaN                        NaN
# 2                 NaN                        NaN
# 3                 NaN                        NaN
# 4                 NaN                        NaN
# 5                 NaN                        NaN
# 6                 NaN                        NaN
# 7                 NaN                        NaN
# 8                 NaN                        NaN
# 9                 NaN                        NaN
# 10                NaN                        NaN
# 11                NaN                        NaN
# 12                NaN                        NaN
# 13                NaN                        NaN
# 14                NaN                        NaN
# 15                NaN                        NaN
# 16                NaN                        NaN
# 17                NaN                        NaN
# 18                NaN                        NaN
# 19                NaN                        NaN
# 20                NaN                        NaN
# 21                NaN                        NaN
# 22                NaN                        NaN
# 23                NaN                        NaN
# 24            93763.0                     4704.0
# 25            75121.0                     6097.0
# 26            65396.0                     2839.0
# 27            86317.0                     8061.0
# 28           489717.0                    31741.0
# 29            36779.0                     1843.0
# 30            41491.0                     1193.0
# 31            90850.0                     7004.0
# 32           102989.0                     5193.0
# 33            81608.0                     6823.0
# 34            69921.0                     3080.0
# 35           100240.0                     8223.0
# 36           537774.0                    34318.0
# 37            38528.0                     2161.0
# 38            43468.0                     1335.0
# 39           101020.0                     7503.0
# 40           111684.0                     5377.0
# 41            86845.0                     5626.0
# 42            74986.0                     3512.0
# 43           106805.0                     9046.0
# 44           578652.0                    34085.0
# 45            42601.0                      812.0
# 46            46970.0                     1584.0
# 47           108761.0                     8128.0
# 48           123929.0                     5665.0
# 49            89928.0                     8546.0
#
# [50 rows x 59 columns]

# %%
###export the file to get an overview
df_health.to_excel('../app/data/df_health.xlsx', index=False)

# %%
df_health["Kost_Total"] = df_health["KostAmbA"] + df_health["KostStatA"]
df_health.head()
# Out:
#    Jahr             Region      KostAmbA     KostStatA Anzahl_Spitaeler_GrVe  \
# 0  2010  Espace Mittelland  1.003112e+09  2.687294e+09                    14
# 1  2010    Nordwestschweiz  7.039205e+08  1.632927e+09                    10
# 2  2010         Ostschweiz  4.827668e+08  1.504621e+09                    20
# 3  2010   Région lémanique  9.297511e+08  2.268943e+09                    16
# 4  2010            Schweiz  4.498723e+09  1.207283e+10                    91
#
#   Anzahl_Spitaeler_ZeVe Anzahl_Spitaeler_AllgKr Betten_Total_GrVe  \
# 0                     8                      22              1610
# 1                     5                      15              1059
# 2                     3                      23              1557
# 3                     7                      23              1696
# 4                    30                     121              9085
#
#   Betten_Total_ZeVe Betten_Total_AllgKr  ... PET_SCANNER_Geräte  \
# 0              3943                5553  ...                NaN
# 1              2372                3431  ...                NaN
# 2              1687                3244  ...                NaN
# 3              4862                6559  ...                NaN
# 4             17031               26116  ...                NaN
#
#   ANGIOGRAPHIE_Untersuchungen CT_SCANNER_Untersuchungen  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#   DIALYSE_Untersuchungen GAMMA_CAMERA_Untersuchungen  \
# 0                    NaN                         NaN
# 1                    NaN                         NaN
# 2                    NaN                         NaN
# 3                    NaN                         NaN
# 4                    NaN                         NaN
#
#   LINEARBESCHLEUNIGER_Untersuchungen LITHOTRIPTOR_Untersuchungen  \
# 0                                NaN                         NaN
# 1                                NaN                         NaN
# 2                                NaN                         NaN
# 3                                NaN                         NaN
# 4                                NaN                         NaN
#
#   MRI_Untersuchungen PET_SCANNER_Untersuchungen    Kost_Total
# 0                NaN                        NaN  3.690406e+09
# 1                NaN                        NaN  2.336847e+09
# 2                NaN                        NaN  1.987388e+09
# 3                NaN                        NaN  3.198694e+09
# 4                NaN                        NaN  1.657156e+10
#
# [5 rows x 60 columns]

# %%
df_staff_melt.head()
# Out:
#     Region  Jahr  MedTechPersonal_Anz_GrVe  MedTechPersonal_Anz_ZeVe  \
# 0  Schweiz  2010                   3556.61                   7200.44
# 1  Schweiz  2011                   3458.05                   7617.76
# 2  Schweiz  2012                   3294.98                   7897.32
# 3  Schweiz  2013                   2358.83                   8379.71
# 4  Schweiz  2014                   2194.96                   8548.09
#
#    MedTechPersonal_Anz_AllgKr  MedTheraPersonal_Anz_GrVe  \
# 0                    10757.05                    1104.33
# 1                    11075.81                    1069.25
# 2                    11192.30                    1058.45
# 3                    10738.54                     890.91
# 4                    10743.05                     936.47
#
#    MedTheraPersonal_Anz_ZeVe  MedTheraPersonal_Anz_AllgKr  \
# 0                    2377.39                      3481.72
# 1                    2456.84                      3526.09
# 2                    2700.40                      3758.85
# 3                    2981.75                      3872.66
# 4                    3083.09                      4019.56
#
#    Pflegepersonal_Anz_GrVe  Pflegepersonal_Anz_ZeVe  \
# 0                 14636.39                 32955.09
# 1                 14319.46                 33384.39
# 2                 14046.32                 34602.52
# 3                 10710.22                 39254.60
# 4                 11216.52                 40307.35
#
#    Pflegepersonal_Anz_AllgKr  Ärzteschaft_Anz_GrVe  Ärzteschaft_Anz_ZeVe  \
# 0                   47591.48               3568.65              12154.95
# 1                   47703.85               3608.74              12851.99
# 2                   48648.84               3483.40              13212.17
# 3                   49964.82               2588.36              14364.39
# 4                   51523.87               2725.99              14799.93
#
#    Ärzteschaft_Anz_AllgKr
# 0                15723.60
# 1                16460.73
# 2                16695.57
# 3                16952.75
# 4                17525.92

# %%
df_infrastructure_melt.head()
# Out:
#     Region  Jahr  ANGIOGRAPHIE_Geräte  CT_SCANNER_Geräte  DIALYSE_Geräte  \
# 0  Schweiz  2013                  137                194            1141
# 1  Schweiz  2014                  138                201            1142
# 2  Schweiz  2015                  146                201            1152
# 3  Schweiz  2016                  143                205            1182
# 4  Schweiz  2017                  136                211            1225
#
#    GAMMA_CAMERA_Geräte  LINEARBESCHLEUNIGER_Geräte  LITHOTRIPTOR_Geräte  \
# 0                   68                          52                   34
# 1                   65                          57                   37
# 2                   64                          57                   34
# 3                   63                          57                   32
# 4                   62                          57                   31
#
#    MRI_Geräte  PET_SCANNER_Geräte  ANGIOGRAPHIE_Untersuchungen  \
# 0         162                  28                       105713
# 1         172                  29                       116967
# 2         183                  28                       119395
# 3         188                  28                       121854
# 4         197                  28                       118025
#
#    CT_SCANNER_Untersuchungen  DIALYSE_Untersuchungen  \
# 0                     730432                  383943
# 1                     804455                  411329
# 2                     830373                  428160
# 3                     870914                  424402
# 4                     928960                  430398
#
#    GAMMA_CAMERA_Untersuchungen  LINEARBESCHLEUNIGER_Untersuchungen  \
# 0                        98765                              334002
# 1                        92719                              321444
# 2                       113005                              313595
# 3                        98821                              325026
# 4                        91661                              327413
#
#    LITHOTRIPTOR_Untersuchungen  MRI_Untersuchungen  PET_SCANNER_Untersuchungen
# 0                         6061              489717                       31741
# 1                         6845              537774                       34318
# 2                         6370              578652                       34085
# 3                         5714              604485                       40403
# 4                         5703              626538                       45165

# %%
column_devices = ["ANGIOGRAPHIE_Geräte", "CT_SCANNER_Geräte", "DIALYSE_Geräte", "GAMMA_CAMERA_Geräte", "LINEARBESCHLEUNIGER_Geräte",	"LITHOTRIPTOR_Geräte", "MRI_Geräte", "PET_SCANNER_Geräte"]
df_health["Total Devices"] = df_health[column_devices].sum(axis=1)

# %%
column_examination = ["ANGIOGRAPHIE_Untersuchungen", "CT_SCANNER_Untersuchungen", "DIALYSE_Untersuchungen", "GAMMA_CAMERA_Untersuchungen", "LINEARBESCHLEUNIGER_Untersuchungen", "LITHOTRIPTOR_Untersuchungen", "MRI_Untersuchungen", "PET_SCANNER_Untersuchungen"]
df_health["Total Examinations"] = df_health[column_examination].sum(axis=1)

# %%
df_health
# Out:
#      Jahr             Region      KostAmbA     KostStatA  \
# 0    2010  Espace Mittelland  1.003112e+09  2.687294e+09
# 1    2010    Nordwestschweiz  7.039205e+08  1.632927e+09
# 2    2010         Ostschweiz  4.827668e+08  1.504621e+09
# 3    2010   Région lémanique  9.297511e+08  2.268943e+09
# 4    2010            Schweiz  4.498723e+09  1.207283e+10
# ..    ...                ...           ...           ...
# 107  2023   Région lémanique  2.067036e+09  3.403949e+09
# 108  2023            Schweiz  9.227304e+09  1.693895e+10
# 109  2023             Ticino  3.787368e+08  6.850371e+08
# 110  2023     Zentralschweiz  7.490906e+08  1.254411e+09
# 111  2023             Zürich  1.612881e+09  3.569985e+09
#
#     Anzahl_Spitaeler_GrVe Anzahl_Spitaeler_ZeVe Anzahl_Spitaeler_AllgKr  \
# 0                      14                     8                      22
# 1                      10                     5                      15
# 2                      20                     3                      23
# 3                      16                     7                      23
# 4                      91                    30                     121
# ..                    ...                   ...                     ...
# 107                    13                     7                      20
# 108                    57                    44                     101
# 109                     3                     1                       4
# 110                     7                     3                      10
# 111                     4                    10                      14
#
#     Betten_Total_GrVe Betten_Total_ZeVe Betten_Total_AllgKr  ...  \
# 0                1610              3943                5553  ...
# 1                1059              2372                3431  ...
# 2                1557              1687                3244  ...
# 3                1696              4862                6559  ...
# 4                9085             17031               26116  ...
# ..                ...               ...                 ...  ...
# 107              1108              5069                6178  ...
# 108              4369             18863               23232  ...
# 109                 X                 X                1331  ...
# 110               485              1100                1584  ...
# 111               429              3023                3452  ...
#
#     CT_SCANNER_Untersuchungen DIALYSE_Untersuchungen  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
# 2                         NaN                    NaN
# 3                         NaN                    NaN
# 4                         NaN                    NaN
# ..                        ...                    ...
# 107                  230351.0                82278.0
# 108                 1242095.0               456529.0
# 109                  101835.0                29788.0
# 110                   94397.0                34439.0
# 111                  234628.0                62709.0
#
#     GAMMA_CAMERA_Untersuchungen LINEARBESCHLEUNIGER_Untersuchungen  \
# 0                           NaN                                NaN
# 1                           NaN                                NaN
# 2                           NaN                                NaN
# 3                           NaN                                NaN
# 4                           NaN                                NaN
# ..                          ...                                ...
# 107                     15210.0                            90086.0
# 108                     94929.0                           399087.0
# 109                     17145.0                            14522.0
# 110                      8784.0                            22136.0
# 111                     18273.0                            84130.0
#
#     LITHOTRIPTOR_Untersuchungen MRI_Untersuchungen PET_SCANNER_Untersuchungen  \
# 0                           NaN                NaN                        NaN
# 1                           NaN                NaN                        NaN
# 2                           NaN                NaN                        NaN
# 3                           NaN                NaN                        NaN
# 4                           NaN                NaN                        NaN
# ..                          ...                ...                        ...
# 107                       464.0           153495.0                    19067.0
# 108                      2130.0           816419.0                    79800.0
# 109                        20.0            60249.0                     4258.0
# 110                       445.0            76250.0                     4070.0
# 111                       140.0           143396.0                    14851.0
#
#        Kost_Total Total Devices Total Examinations
# 0    3.690406e+09           0.0                0.0
# 1    2.336847e+09           0.0                0.0
# 2    1.987388e+09           0.0                0.0
# 3    3.198694e+09           0.0                0.0
# 4    1.657156e+10           0.0                0.0
# ..            ...           ...                ...
# 107  5.470985e+09         407.0           615008.0
# 108  2.616625e+10        2180.0          3215075.0
# 109  1.063774e+09         145.0           235664.0
# 110  2.003502e+09         187.0           246564.0
# 111  5.182867e+09         348.0           582688.0
#
# [112 rows x 62 columns]

# %% [markdown]
# Tidy Data : )

# %%
df_health= df_health.drop(columns=[
    "Betten_akut_GrVe",
    "Betten_akut_ZeVe",
    "Betten_akut_AllgKr",
    "Betten_geb_GrVe",
    "Betten_geb_ZeVe",
    "Betten_geb_AllgKr",
    "Betten_psy_GrVe",
    "Betten_psy_ZeVe",
    "Betten_psy_AllgKr",
    "Betten_reha_GrVe",
    "Betten_reha_ZeVe",
    "Betten_reha_AllgKr",
    "Pflegetage_M_365_GrVe",
    "Pflegetage_M_365_ZeVe",
    "Pflegetage_M_365_AllgKr",])

# %%
df_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 47 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Jahr                                112 non-null    int64
#  1   Region                              112 non-null    object
#  2   KostAmbA                            112 non-null    float64
#  3   KostStatA                           112 non-null    float64
#  4   Anzahl_Spitaeler_GrVe               112 non-null    object
#  5   Anzahl_Spitaeler_ZeVe               112 non-null    object
#  6   Anzahl_Spitaeler_AllgKr             112 non-null    object
#  7   Betten_Total_GrVe                   112 non-null    object
#  8   Betten_Total_ZeVe                   112 non-null    object
#  9   Betten_Total_AllgKr                 112 non-null    object
#  10  Bettenbelegung_GrVe                 112 non-null    object
#  11  Bettenbelegung_ZeVe                 112 non-null    object
#  12  Bettenbelegung_AllgKr               112 non-null    object
#  13  Bettenbetriebstage_GrVe             112 non-null    object
#  14  Bettenbetriebstage_ZeVe             112 non-null    object
#  15  Bettenbetriebstage_AllgKr           112 non-null    object
#  16  MedTechPersonal_Anz_GrVe            112 non-null    float64
#  17  MedTechPersonal_Anz_ZeVe            112 non-null    float64
#  18  MedTechPersonal_Anz_AllgKr          112 non-null    float64
#  19  MedTheraPersonal_Anz_GrVe           112 non-null    float64
#  20  MedTheraPersonal_Anz_ZeVe           112 non-null    float64
#  21  MedTheraPersonal_Anz_AllgKr         112 non-null    float64
#  22  Pflegepersonal_Anz_GrVe             112 non-null    float64
#  23  Pflegepersonal_Anz_ZeVe             112 non-null    float64
#  24  Pflegepersonal_Anz_AllgKr           112 non-null    float64
#  25  Ärzteschaft_Anz_GrVe                112 non-null    float64
#  26  Ärzteschaft_Anz_ZeVe                112 non-null    float64
#  27  Ärzteschaft_Anz_AllgKr              112 non-null    float64
#  28  ANGIOGRAPHIE_Geräte                 88 non-null     float64
#  29  CT_SCANNER_Geräte                   88 non-null     float64
#  30  DIALYSE_Geräte                      88 non-null     float64
#  31  GAMMA_CAMERA_Geräte                 88 non-null     float64
#  32  LINEARBESCHLEUNIGER_Geräte          88 non-null     float64
#  33  LITHOTRIPTOR_Geräte                 88 non-null     float64
#  34  MRI_Geräte                          88 non-null     float64
#  35  PET_SCANNER_Geräte                  88 non-null     float64
#  36  ANGIOGRAPHIE_Untersuchungen         88 non-null     float64
#  37  CT_SCANNER_Untersuchungen           88 non-null     float64
#  38  DIALYSE_Untersuchungen              88 non-null     float64
#  39  GAMMA_CAMERA_Untersuchungen         88 non-null     float64
#  40  LINEARBESCHLEUNIGER_Untersuchungen  88 non-null     float64
#  41  LITHOTRIPTOR_Untersuchungen         88 non-null     float64
#  42  MRI_Untersuchungen                  88 non-null     float64
#  43  PET_SCANNER_Untersuchungen          88 non-null     float64
#  44  Kost_Total                          112 non-null    float64
#  45  Total Devices                       112 non-null    float64
#  46  Total Examinations                  112 non-null    float64
# dtypes: float64(33), int64(1), object(13)
# memory usage: 41.3+ KB

# %%
df_health = df_health.rename(columns={
    "Jahr": "Year",
    "Region": "Region",
    "KostAmbA": "Cost_AcuteCare_Amb",
    "KostStatA": "Cost_AcuteCare_Stat",
    "Anzahl_Spitaeler_GrVe": "Amount_Hospitals_Basic",
    "Anzahl_Spitaeler_ZeVe": "Amount_Hospitals_Central",
    "Anzahl_Spitaeler_AllgKr": "Amount_Hospitals_General",
    "Betten_Total_GrVe": "Beds_Total_Basic",
    "Betten_Total_ZeVe": "Beds_Total_Central",
    "Betten_Total_AllgKr": "Beds_Total_General",
    "Bettenbelegung_GrVe": "Bed_Occupancy_Basic",
    "Bettenbelegung_ZeVe": "Bed_Occupancy_Central",
    "Bettenbelegung_AllgKr": "Bed_Occupancy_General",
    "Bettenbetriebstage_GrVe": "Bed_OccupancyDays_Basic",
    "Bettenbetriebstage_ZeVe": "Bed_OccupancyDays_Central",
    "Bettenbetriebstage_AllgKr": "Bed_OccupancyDays_General",
    "MedTechPersonal_Anz_GrVe": "MedTec_Amount_Basic",
    "MedTechPersonal_Anz_ZeVe": "MedTec_Amount_Central",
    "MedTechPersonal_Anz_AllgKr": "MedTec_Amount_General",
    "MedTheraPersonal_Anz_GrVe": "MedThe_Amount_Basic",
    "MedTheraPersonal_Anz_ZeVe": "MedThe_Amount_Central",
    "MedTheraPersonal_Anz_AllgKr":"MedThe_Amount_General",
    "Pflegepersonal_Anz_GrVe": "Nurses_Amount_Basic",
    "Pflegepersonal_Anz_ZeVe": "Nurses_Amount_Central",
    "Pflegepersonal_Anz_AllgKr": "Nurses_Amount_General",
    "Ärzteschaft_Anz_GrVe": "Doctors_Amount_Basic",
    "Ärzteschaft_Anz_ZeVe": "Doctors_Amount_Central",
    "Ärzteschaft_Anz_AllgKr": "Doctors_Amount_General",
    "ANGIOGRAPHIE_Geräte": "Angiographie_Device",
    "CT_SCANNER_Geräte": "CT_Scanner_Device",
    "DIALYSE_Geräte": "Dialyse_Device",
    "GAMMA_CAMERA_Geräte": "Gamma_Camera_Device",
    "LINEARBESCHLEUNIGER_Geräte": "Linear_Accelerator_Device",
    "LITHOTRIPTOR_Geräte": "Lithotriptor_Device",
    "MRI_Geräte": "MRI_Device",
    "PET_SCANNER_Geräte": "Pet_Scanner_Device",
    "ANGIOGRAPHIE_Untersuchungen": "Angiographie_Examination",
    "CT_SCANNER_Untersuchungen": "CT_Scanner_Examination",
    "DIALYSE_Untersuchungen": "Dialyse_Examination",
    "GAMMA_CAMERA_Untersuchungen": "Gamma_Camera_Examination",
    "LINEARBESCHLEUNIGER_Untersuchungen": "Linear_Accelerator_Examination",
    "LITHOTRIPTOR_Untersuchungen": "Lithotriptor_Examination",
    "MRI_Untersuchungen": "MRI_Examination",
    "PET_SCANNER_Untersuchungen": "Pet_Scanner_Examination",
    "Kost_Total": "Cost_Total"
 })

# %%
###export the file to get an overview for the second time
df_health.to_excel('../app/data/df_health.xlsx', index=False)
